# %% [markdown]
# <div style="border:solid green 2px; padding: 20px">
#
# <b>Дмитрий, привет!</b> Мы рады тебя видеть на территории код-ревьюеров 😎. Ты проделал большую работу над проектом, но давай познакомимся и сделаем его еще лучше! У нас тут своя атмосфера и несколько правил:
#
#
# 1. Меня зовут Александр Матвеевский. Я работаю код-ревьюером, моя основная цель — не указать на совершенные тобою ошибки, а поделиться своим опытом и помочь тебе стать аналитиком данных.
# 2. Общаемся на ты.
# 3. Если хочешь написать, спросить - не нужно стесняться. Только выбери свой цвет для комментария.
# 4. Это учебный проект, тут можно не бояться сделать ошибку.
# 5. У нас с тобой 6 попыток для сдачи проекта
# 6. Let's Go!
#
# ---
#
# Я буду красить комментарии цветом, пожалуйста, не удаляй их:
#
# <div class="alert alert-block alert-danger">✍
#
#
# __Комментарий от ревьюера №1__
#
# Такой комментарий нужно исправить обязательно, он критически влияет на удачное выполнение проекта.
# </div>
#
# ---
#
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №1__
#
#
# Такой комментарий является рекомендацией или советом. Можешь использовать их на своё усмотрение.
# </div>
#
# ---
#
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Такой комментарий  говорит о том, что было сделано что-то качественное и правильное =)
# </div>
#
# ---
#
# Предлагаю работать над проектом в диалоге: если ты что-то меняешь в проекте или отвечаешь на мои комментарии — пиши об этом. Мне будет легче отследить изменения, если ты выделишь свои комментарии:
#
# <div class="alert alert-info"> <b>Комментарии студента:</b> Например, вот так.</div>
#
# Всё это поможет выполнить повторную проверку твоего проекта оперативнее. Если будут какие-нибудь вопросы по моим комментариям, пиши, будем разбираться вместе :)
#
# ---

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарии студента:</b> Добрый день Александр! Благодарю за ваше ревью! Очень рад, что моя работа вызвала у вас положительные эмоции. Я старался сделать все максимально понятно и наглядно. Если будут дополнительные вопросы или пожелания, всегда готов обсудить. Ваша обратная связь очень ценна для меня..</div>

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №2__
#
# Дмитрий, рад тебя видеть =) Спасибо тебе за обратную связь и крутой проект ^^

# %% [markdown]
# # Анализ бизнес-показателей приложения Procrastinate Pro+

# %% [markdown]
# Требуется провести маркетинговую аналитику развлекательного приложения Procrastinate Pro+.
# Несмотря на огромные вложения в рекламу, последние несколько месяцев компания терпит убытки.
# Имеются данные о пользователях, привлечённых с 1 мая по 27 октября 2019 года:
#
# * лог сервера с данными об их посещениях,
#
# * выгрузка их покупок за этот период,
#
# * рекламные расходы.

# %% [markdown]
# **Нам предстоит изучить:**
#
# * откуда приходят пользователи и какими устройствами они пользуются,
#
#
# * сколько стоит привлечение пользователей из различных рекламных каналов;
#
#
# * сколько денег приносит каждый клиент,
#
#
# * когда расходы на привлечение клиента окупаются,
#
#
# * какие факторы мешают привлечению клиентов.

# %% [markdown]
# **Цель исследования:**
#
# Разобраться в причинах убытков компании и помочь ей выйти в плюс.

# %% [markdown]
# **Описание данных:**
#
# В нашем распоряжении три датасета.
#
# 1. `visits_info_short.csv` — хранит лог сервера с информацией о посещениях сайта.
#
# Структура:
#
# * `User Id` — уникальный идентификатор пользователя,
#
# * `Region` — страна пользователя,
#
# * `Device` — тип устройства пользователя,
#
# * `Channel` — идентификатор источника перехода,
#
# * `Session Start` — дата и время начала сессии,
#
# * `Session End` — дата и время окончания сессии.

# %% [markdown]
# 2. `orders_info_short.csv` — хранит информацию о заказах.
#
# Структура:
#
# * `User Id` — уникальный идентификатор пользователя,
#
# * `Event Dt` — дата и время покупки,
#
# * `Revenue` — сумма заказа.

# %% [markdown]
# 3. `costs_info_short.csv` — хранит информацию о расходах на рекламу.
#
# Структура:
#
# * `dt` — дата проведения рекламной кампании,
#
# * `Channel` — идентификатор рекламного источника,
#
# * `costs` — расходы на эту кампанию.

# %% [markdown]
# **Этапы исследования:**
#
# 1. Обзор данных,
#
# 2. Предобработка данных,
#
# 3. Исследовательский анализ данных,
#
# 4. Анализ маркетинговых расходов,
#
# 5. Оценка окупаемости рекламы,
#
# 6. Вывод.

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
#
# Отличная практика - расписывать цель и основные этапы своими словами (этот навык очень поможет на фильнальном проекте).
# </div>

# %% [markdown]
# ### Загрузите данные и подготовьте их к анализу

# %% [markdown]
# Загрузите данные о визитах, заказах и рекламных расходах из CSV-файлов в переменные.
#
# **Пути к файлам**
#
# - визиты: `/datasets/visits_info_short.csv`. [Скачать датасет](https://code.s3.yandex.net/datasets/visits_info_short.csv);
# - заказы: `/datasets/orders_info_short.csv`. [Скачать датасет](https://code.s3.yandex.net/datasets/orders_info_short.csv);
# - расходы: `/datasets/costs_info_short.csv`. [Скачать датасет](https://code.s3.yandex.net/datasets/costs_info_short.csv).
#
# Изучите данные и выполните предобработку. Есть ли в данных пропуски и дубликаты? Убедитесь, что типы данных во всех колонках соответствуют сохранённым в них значениям. Обратите внимание на столбцы с датой и временем.

# %%
# Импортируем необходимые библиотеки

import pandas as pd
import numpy as np
import seaborn as sns
from datetime import datetime, timedelta
from matplotlib import pyplot as plt
sns.set(style="whitegrid")
# %matplotlib inline

# %%
# Чтение файлов с данными и сохранение в df

try:
    visits_info, orders_info, costs_info = (
        pd.read_csv('/datasets/visits_info_short.csv'),  # визиты
        pd.read_csv('/datasets/orders_info_short.csv'),  # заказы
        pd.read_csv('/datasets/costs_info_short.csv')    # расходы
    )


except:
    visits_info, orders_info, costs_info = (
        pd.read_csv('visits_info_short.csv'),            # визиты
        pd.read_csv('orders_info_short.csv'),            # заказы
        pd.read_csv('costs_info_short.csv')              # расходы
    )

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
#
# __Комментарий от ревьюера №1__
#
# Здорово, что для подгрузки данных используешь конструкцию `try-except`, она поможет избежать потенциальных ошибок при загрузке данных, связанных, например, с некорректным указанием путей.
#
# Подробнее о конструкции по ссылке:
#
# https://pythonworld.ru/tipy-dannyx-v-python/isklyucheniya-v-python-konstrukciya-try-except-dlya-obrabotki-isklyuchenij.html
#
# Либо же можно использовать стандартную библиотеку os:
#
# https://pythonworld.ru/moduli/modul-os.html
#
#
# Несколько интересных статей кейсы использования конструкции:
#
# https://www.programiz.com/python-programming/exception-handling
#
# https://towardsdatascience.com/do-not-abuse-try-except-in-python-d9b8ee59e23b
#
# https://www.techbeamers.com/use-try-except-python/
#
# Как вариант в try можно указать корректные пути (в нашем случае глобальные) в except - некорректные (локальные). Можно также специфицровать тип ошибки, FileNotFoundError или задать кастомный тип ошибки (FilePathError, например)
#
# Она полезна, если ты работаешь локально, а потом подгружаешь проект на платформу. Конструкция позволит не падать коду и локально, и на сервере ЯП, так как если не сработает один блок с путями, сработает другой.
#
# Ну и вообще, в целом полезно про эту констуркцию знать, она универсальна и может быть использована в разных задачах.

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарии студента:</b> Приму к сведению и обязательно изучу этот вопрос!!!</div>

# %% [markdown]
# Для начала, проверим каждый из датафреймов на наличие пропусков и дубликатов, затем убедимся, что типы данных соответствуют содержимому, и, наконец, приведём названия столбцов к _"змеиному стилю"_.

# %% [markdown]
# **Датафрейм `visits_info`:**

# %%
# Проверка пропущенных значений в visits_info
missing_values_visits = visits_info.isnull().sum()

# Проверка дубликатов в visits_info
duplicates_visits = visits_info.duplicated().sum()

# Проверка типов данных в visits_info
data_types_visits = visits_info.dtypes

missing_values_visits, duplicates_visits, data_types_visits
# Out:
# (User Id          0
#  Region           0
#  Device           0
#  Channel          0
#  Session Start    0
#  Session End      0
#  dtype: int64,
#  0,
#  User Id           int64
#  Region           object
#  Device           object
#  Channel          object
#  Session Start    object
#  Session End      object
#  dtype: object)

# %%
visits_info.head()
# Out:
#         User Id         Region   Device  Channel        Session Start  \
# 0  981449118918  United States   iPhone  organic  2019-05-01 02:36:01
# 1  278965908054  United States   iPhone  organic  2019-05-01 04:46:31
# 2  590706206550  United States      Mac  organic  2019-05-01 14:09:25
# 3  326433527971  United States  Android   TipTop  2019-05-01 00:29:59
# 4  349773784594  United States      Mac  organic  2019-05-01 03:33:35
#
#            Session End
# 0  2019-05-01 02:45:01
# 1  2019-05-01 04:47:35
# 2  2019-05-01 15:32:08
# 3  2019-05-01 00:54:25
# 4  2019-05-01 03:57:40

# %% [markdown]
# > В датафрейме `visits_info`:
# >
# >1. Пропусков нет.
# >
# >2. Дубликатов нет.
# >
# >3. Типы данных:
# >    * __User Id__, __Region__, __Device__, и __Channel__ имеют ожидаемые типы данных.
# >
# >    * Столбцы __Session Start__ и __Session End__ содержат строковые значения, которые представляют дату и время.
# >    Их следует преобразовать в тип datetime.

# %% [markdown]
# Приведём названия столбцов к _"змеиному стилю"_ и затем преобразуем столбцы с датой и временем в соответствующий формат:

# %%
# Переименование столбцов
visits_info.columns = ['user_id', 'region', 'device', 'channel', 'session_start', 'session_end']

# Преобразование столбцов 'session_start' и 'session_end' в формат даты и времени
visits_info['session_start'] = pd.to_datetime(visits_info['session_start'])
visits_info['session_end'] = pd.to_datetime(visits_info['session_end'])

visits_info.info(),
visits_info.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 309901 entries, 0 to 309900
# Data columns (total 6 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   user_id        309901 non-null  int64
#  1   region         309901 non-null  object
#  2   device         309901 non-null  object
#  3   channel        309901 non-null  object
#  4   session_start  309901 non-null  datetime64[ns]
#  5   session_end    309901 non-null  datetime64[ns]
# dtypes: datetime64[ns](2), int64(1), object(3)
# memory usage: 14.2+ MB
#         user_id         region   device  channel       session_start  \
# 0  981449118918  United States   iPhone  organic 2019-05-01 02:36:01
# 1  278965908054  United States   iPhone  organic 2019-05-01 04:46:31
# 2  590706206550  United States      Mac  organic 2019-05-01 14:09:25
# 3  326433527971  United States  Android   TipTop 2019-05-01 00:29:59
# 4  349773784594  United States      Mac  organic 2019-05-01 03:33:35
# ...

# %% [markdown]
#  **Датафрейм `orders_info`:**

# %%
# Проверка пропущенных значений в order_info
missing_values_orders = orders_info.isnull().sum()

# Проверка дубликатов в order_info
duplicates_orders = orders_info.duplicated().sum()

# Проверка типов данных в order_info
data_types_orders = orders_info.dtypes

missing_values_orders, duplicates_orders, data_types_orders
# Out:
# (User Id     0
#  Event Dt    0
#  Revenue     0
#  dtype: int64,
#  0,
#  User Id       int64
#  Event Dt     object
#  Revenue     float64
#  dtype: object)

# %%
orders_info.head()
# Out:
#         User Id             Event Dt  Revenue
# 0  188246423999  2019-05-01 23:09:52     4.99
# 1  174361394180  2019-05-01 12:24:04     4.99
# 2  529610067795  2019-05-01 11:34:04     4.99
# 3  319939546352  2019-05-01 15:34:40     4.99
# 4  366000285810  2019-05-01 13:59:51     4.99

# %% [markdown]
# >В датафрейме `orders_info`:
# >
# >1. Пропусков нет.
# >2. Дубликатов нет.
# >3. Типы данных:
# >    * __User Id__ и __Revenue__ имеют ожидаемые типы данных.
# >    * Столбец __Event Dt__ содержит строковые значения, которые представляют дату и время.
# >    Его следует преобразовать в тип datetime.

# %% [markdown]
# Приведём названия столбцов к _"змеиному стилю"_ и затем преобразуем столбец с датой и временем в соответствующий формат:

# %%
# Переименование столбцов
orders_info.columns = ['user_id', 'event_dt', 'revenue']

# Преобразование столбца 'event_dt' в формат даты и времени
orders_info['event_dt'] = pd.to_datetime(orders_info['event_dt'])

orders_info.info(),
orders_info.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40212 entries, 0 to 40211
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   user_id   40212 non-null  int64
#  1   event_dt  40212 non-null  datetime64[ns]
#  2   revenue   40212 non-null  float64
# dtypes: datetime64[ns](1), float64(1), int64(1)
# memory usage: 942.6 KB
#         user_id            event_dt  revenue
# 0  188246423999 2019-05-01 23:09:52     4.99
# 1  174361394180 2019-05-01 12:24:04     4.99
# 2  529610067795 2019-05-01 11:34:04     4.99
# 3  319939546352 2019-05-01 15:34:40     4.99
# 4  366000285810 2019-05-01 13:59:51     4.99

# %% [markdown]
# **Датафрейм `costs_info`:**

# %%
# Проверка пропущенных значений в costs_info
missing_values_costs = costs_info.isnull().sum()

# Проверка дубликатов в costs_info
duplicates_costs = costs_info.duplicated().sum()

# Проверка типов данных в costs_info
data_types_costs = costs_info.dtypes

missing_values_costs, duplicates_costs, data_types_costs
# Out:
# (dt         0
#  Channel    0
#  costs      0
#  dtype: int64,
#  0,
#  dt          object
#  Channel     object
#  costs      float64
#  dtype: object)

# %%
costs_info.head()
# Out:
#            dt   Channel  costs
# 0  2019-05-01  FaceBoom  113.3
# 1  2019-05-02  FaceBoom   78.1
# 2  2019-05-03  FaceBoom   85.8
# 3  2019-05-04  FaceBoom  136.4
# 4  2019-05-05  FaceBoom  122.1

# %%
costs_info.sample(10)
# Out:
#               dt             Channel    costs
# 1291  2019-06-01  OppleCreativeMedia   15.750
# 455   2019-08-04      RocketSuperAds   10.465
# 93    2019-08-02            FaceBoom  218.900
# 1485  2019-06-15      WahooNetBanner   25.800
# 1293  2019-06-03  OppleCreativeMedia   13.250
# 340   2019-10-08        MediaTornado    3.600
# 1036  2019-09-14          AdNonSense   11.550
# 766   2019-06-16             YRabbit    2.700
# 74    2019-07-14            FaceBoom  182.600
# 1498  2019-06-28      WahooNetBanner   39.000

# %% [markdown]
# >В датафрейме `costs_info`:
# >
# >1. Пропусков нет.
# >2. Дубликатов нет.
# >3. Типы данных:
# >    * __Channel__ и __costs__ имеют ожидаемые типы данных.
# >    * Столбец __dt__ содержит строковые значения, представляющие дату.
# >    Его следует преобразовать в тип datetime.

# %% [markdown]
# Приведём названия столбцов к _"змеиному стилю"_ и преобразуем столбец с датой в соответствующий формат:

# %%
# Переименование столбцов
costs_info.columns = ['dt', 'channel', 'costs']

# Преобразование столбца 'dt' в формат даты и времени
costs_info['dt'] = pd.to_datetime(costs_info['dt']).dt.date

costs_info.info()
costs_info.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1800 entries, 0 to 1799
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   dt       1800 non-null   object
#  1   channel  1800 non-null   object
#  2   costs    1800 non-null   float64
# dtypes: float64(1), object(2)
# memory usage: 42.3+ KB
#            dt   channel  costs
# 0  2019-05-01  FaceBoom  113.3
# 1  2019-05-02  FaceBoom   78.1
# 2  2019-05-03  FaceBoom   85.8
# 3  2019-05-04  FaceBoom  136.4
# 4  2019-05-05  FaceBoom  122.1

# %% [markdown]
# **Итоги предобработки:**
#
# >`visits_info`:
# >
# >* Пропусков и дубликатов не обнаружено.
# >* Столбцы __session_start__ и __session_end__ преобразованы в формат datetime.
# >* Названия столбцов приведены к змеиному стилю.
# >
# >`orders_info`:
# >
# >* Пропусков и дубликатов не обнаружено.
# >* Столбец __event_dt__ преобразован в формат datetime.
# >* Названия столбцов приведены к змеиному стилю.
# >
# >`costs_info`:
# >
# >* Пропусков и дубликатов не обнаружено.
# >* Столбец __dt__ преобразован в формат datetime.
# >* Названия столбцов приведены к змеиному стилю.

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
#
# Хорошо, основные действия по предобработке сделаны, здорово, что ты не забыли проверить данные на наличие дубликатов.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №1__
#
#
# * чтобы переименовать колонки, можно также использовать метод `rename()`
#
#
# * если мы только привели преобразование в строчные символы и заменили пробел на знак `_`, то мы можем использовать такой подход:
#
# `visits.columns = visits.columns.str.lower().str.replace(' ', '_')`
#
# также интересным является подход с использованием list comprehensions:
#
# `visits.columns = [x.lower().replace(' ', '_') for x in visits.columns.values]`
#
# * на стадии загрузки и подготовки данных к исследовательскому анализу, советую посмотреть на данные более детально, чтобы избежать невынужденных ошибок в дальнейшем. Чем большем мы знаем о данных - тем более корректны и обоснованы выглядят наши выводы. Такие проверки много времени не занимают, но зато мы можем лучше контролировать данные и их анализ. Например, мы можем:
#     - проверить временной интервал на соответствие условию проекта, а также на возможные ошибки (например, проверить случаи, когда окончание сессии было раньше, и так далее);
#     - для численных данных посмотреть на их статистические показатели и проверить их на наличие каких-то ошибок или аномалий (например, нули или отрицательные значения там, где они не должны быть).

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарии студента:</b> Да! этот метод я знаю, спасибо за замечание!
#
# Ниже дополнил подготовку данных к исследовательскому анализу.</div>

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №2__
#
# Супер, старайся, пожалуйста, придерживаться этой стратегии в дальнейших проектах =)
# </div>

# %%
# Вычисление временного интервала для всего набора данных
min_date = visits_info['session_start'].min()
max_date = visits_info['session_start'].max()

# Проверка сеансов, у которых время окончания раньше времени начала
negative_sessions = visits_info[visits_info['session_end'] < visits_info['session_start']]

min_date, max_date, negative_sessions.shape[0]
# Out:
# (Timestamp('2019-05-01 00:00:41'), Timestamp('2019-10-31 23:59:23'), 0)

# %% [markdown]
# На основе проведенного анализа:
#
# **Временной интервал данных:**
#
# Данные охватывают период с 1 мая 2019 года по 31 октября 2019 года.
# Это соответствует шести месяцам, как указано в условиях проекта.
#
# **Некорректные сессии:**
#
# Не было обнаружено сессий, в которых время окончания раньше, чем время начала.

# %%
# Расчет продолжительности сессии
visits_info['session_duration'] = (visits_info['session_end'] - visits_info['session_start']).dt.total_seconds()

# Описательная статистика для столбца session_duration
session_duration_stats = visits_info['session_duration'].describe()

# Проверка аномалий в session_duration
anomalies = {
    'negative_session_duration': visits_info[visits_info['session_duration'] < 0].shape[0],
    'zero_session_duration': visits_info[visits_info['session_duration'] == 0].shape[0]
}

session_duration_stats, anomalies
# Out:
# (count    309901.000000
#  mean       1800.090868
#  std        1803.063525
#  min           0.000000
#  25%         517.000000
#  50%        1244.000000
#  75%        2497.000000
#  max       22257.000000
#  Name: session_duration, dtype: float64,
#  {'negative_session_duration': 0, 'zero_session_duration': 163})

# %% [markdown]
# На основе проведенного анализа продолжительности сессий:
#
# >1. Статистические показатели:
# >
# >    * Средняя продолжительность сессии составляет примерно 1800 секунд (или 30 минут).
# >    * Медианное значение продолжительности сессии составляет 1244 секунд (или примерно 20,7 минут).
# >    * Максимальная продолжительность сессии составляет 22257 секунд (или примерно 6,2 часа).
# >    * 25% сессий имеют продолжительность менее 517 секунд (или примерно 8,6 минут), а 75% сессий имеют продолжительность менее 2497 секунд (или примерно 41,6 минут).
# >
# >2. Аномалии:
# >
# >    * Не обнаружено отрицательных значений продолжительности сессий.
# >    * Обнаружено 163 сессии с продолжительностью 0 секунд. Это может указывать на то, что пользователь закрыл приложение или веб-сайт сразу после открытия или что была техническая ошибка при регистрации сессии.

# %% [markdown]
# Основываясь на анализе продолжительности сессий:
#
# >**Общая динамика:**
# >
# >    * Продолжительность сессии варьируется среди пользователей, с медианной продолжительностью около 20,7 минут.
# >    Это указывает на то, что большинство пользователей проводят в приложении достаточное количество времени,
# >    что может говорить  высоком уровне вовлеченности.
# >
# >**Максимальные и минимальные значения:**
# >
# >    * С учетом максимальной продолжительности сессии в 6,2 часа, некоторые пользователи проводят в приложении
# >    длительное время.
# >    Однако есть и те, кто проводит очень мало времени, возможно, из-за недостатка интереса или технических проблем.
# >
# >**Аномалии:**
# >
# >    * Наличие сессий с продолжительностью 0 секунд может указывать на проблемы. Это может быть связано с тем,
#     что пользователи немедленно закрывают приложение , или с техническими ошибками при регистрации длительности сессии.

# %% [markdown]
# ### Задайте функции для расчёта и анализа LTV, ROI, удержания и конверсии.
#
# Разрешается использовать функции, с которыми вы познакомились в теоретических уроках.
#
# Это функции для вычисления значений метрик:
#
# - `get_profiles()` — для создания профилей пользователей,
# - `get_retention()` — для подсчёта Retention Rate,
# - `get_conversion()` — для подсчёта конверсии,
# - `get_ltv()` — для подсчёта LTV.
#
# А также функции для построения графиков:
#
# - `filter_data()` — для сглаживания данных,
# - `plot_retention()` — для построения графика Retention Rate,
# - `plot_conversion()` — для построения графика конверсии,
# - `plot_ltv_roi` — для визуализации LTV и ROI.

# %% [markdown]
# **Функция `get_profiles()`:**

# %%
def get_profiles(sessions, orders, costs):
    # находим параметры первых посещений
    profiles = (sessions.sort_values(by=['user_id', 'session_start'])
                .groupby('user_id')
                .agg(
                    {
                        'session_start' : 'first',
                        'channel' : 'first',
                        'device' : 'first',
                        'region' : 'first'
                    }
                )
                .rename(columns={'session_start' : 'first_ts'})
                .reset_index()
               )
    
    # для когортного анализа определяем дату первого посещения
    # и первый день месяца, в который это посещение произошло
    profiles['dt'] = profiles['first_ts'].dt.date
    profiles['month'] = profiles['first_ts'].astype('datetime64[M]')
    
    # добавляем признак пользователей, совершивших покупку
    profiles['payer'] = profiles['user_id'].isin(orders['user_id'].unique())
    
    # считаем количество уникальных пользователей
    # с одинаковыми источником и датой привлечения
    new_users = (
        profiles.groupby(['dt', 'channel'])
        .agg({'user_id': 'nunique'})
        .rename(columns={'user_id': 'unique_users'})
        .reset_index()
    )
    
    # объединяем траты на рекламу и число привлечённых пользователей
    ad_costs = costs_info.merge(new_users, on=['dt', 'channel'], how='left')
    
    # делим рекламные расходы на число привлечённых пользователей
    ad_costs['acquisition_cost'] = ad_costs['costs'] / ad_costs['unique_users']
    
    # добавляем стоимость привлечения в профили
    profiles = profiles.merge(
        ad_costs[['dt', 'channel', 'acquisition_cost']],
        on=['dt', 'channel'],
        how='left',
    )

    # стоимость привлечения органических пользователей равна нулю
    profiles['acquisition_cost'] = profiles['acquisition_cost'].fillna(0)
    
    return profiles

# %% [markdown]
# >Функция создает профили пользователей на основе данных о сессиях, заказах и рекламных расходах.
# >
# >Эта функция вычисляет:
# >
# >* Параметры первого посещения пользователя
# >* Признак того, совершил ли пользователь покупку
# >* Дату первого посещения и первый день месяца этого посещения
# >* Стоимость привлечения каждого пользователя
# >
# >Эта функция очень полезна для дальнейшего когортного анализа и вычисления ключевых метрик, таких как Retention Rate, LTV и других.

# %% [markdown]
# **Функция `get_retention()`:**

# %%
def get_retention(
    profiles,
    sessions,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    # добавляем столбец payer в передаваемый dimensions список
    dimensions = ['payer'] + dimensions

    # исключаем пользователей, не «доживших» до горизонта анализа
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')

    # собираем «сырые» данные для расчёта удержания
    result_raw = result_raw.merge(
        sessions[['user_id', 'session_start']], on='user_id', how='left'
    )
    result_raw['lifetime'] = (
        result_raw['session_start'] - result_raw['first_ts']
    ).dt.days

    # функция для группировки таблицы по желаемым признакам
    def group_by_dimensions(df, dims, horizon_days):
        result = df.pivot_table(
            index=dims, columns='lifetime', values='user_id', aggfunc='nunique'
        )
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        result = result.div(result['cohort_size'], axis=0)
        result = result[['cohort_size'] + list(range(horizon_days))]
        result['cohort_size'] = cohort_sizes
        return result

    # получаем таблицу удержания
    result_grouped = group_by_dimensions(result_raw, dimensions, horizon_days)

    # получаем таблицу динамики удержания
    result_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    # возвращаем обе таблицы и сырые данные
    return result_raw, result_grouped, result_in_time

# %% [markdown]
# >Функция рассчитывает коэффициент удержания пользователей.
# >
# >Эта функция:
# >
# >* Исключает пользователей, которые не "дожили" до горизонта анализа.
# >* Собирает "сырые" данные для расчета удержания, добавляя столбец "lifetime", который показывает, сколько дней прошло с момента первого посещения до текущей сессии.
# >* Группирует данные по указанным измерениям (dimensions) и вычисляет удержание для каждой когорты.
# >* Возвращает "сырые" данные, агрегированную таблицу удержания и таблицу динамики удержания во времени.
# >
# >Эта функция позволит изучить удержание пользователей в разрезе различных измерений, таких как источник трафика, устройство и др.

# %% [markdown]
# **Функция `get_conversion()`:**

# %%
# функция для расчёта конверсии

def get_conversion(
    profiles,
    purchases,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    # исключаем пользователей, не «доживших» до горизонта анализа
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')

    # определяем дату и время первой покупки для каждого пользователя
    first_purchases = (
        purchases.sort_values(by=['user_id', 'event_dt'])
        .groupby('user_id')
        .agg({'event_dt': 'first'})
        .reset_index()
    )

    # добавляем данные о покупках в профили
    result_raw = result_raw.merge(
        first_purchases[['user_id', 'event_dt']], on='user_id', how='left'
    )

    # рассчитываем лайфтайм для каждой покупки
    result_raw['lifetime'] = (
        result_raw['event_dt'] - result_raw['first_ts']
    ).dt.days

    # группируем по cohort, если в dimensions ничего нет
    if len(dimensions) == 0:
        result_raw['cohort'] = 'All users' 
        dimensions = dimensions + ['cohort']

    # функция для группировки таблицы по желаемым признакам
    def group_by_dimensions(df, dims, horizon_days):
        result = df.pivot_table(
            index=dims, columns='lifetime', values='user_id', aggfunc='nunique'
        )
        result = result.fillna(0).cumsum(axis = 1)
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        # делим каждую «ячейку» в строке на размер когорты
        # и получаем conversion rate
        result = result.div(result['cohort_size'], axis=0)
        result = result[['cohort_size'] + list(range(horizon_days))]
        result['cohort_size'] = cohort_sizes
        return result

    # получаем таблицу конверсии
    result_grouped = group_by_dimensions(result_raw, dimensions, horizon_days)

    # для таблицы динамики конверсии убираем 'cohort' из dimensions
    if 'cohort' in dimensions: 
        dimensions = []

    # получаем таблицу динамики конверсии
    result_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    # возвращаем обе таблицы и сырые данные
    return result_raw, result_grouped, result_in_time

# %% [markdown]
# >Функция рассчитывает конверсию пользователей.
# >
# >Эта функция:
# >
# >* Исключает пользователей, которые не "дожили" до горизонта анализа.
# >* Определяет дату и время первой покупки для каждого пользователя.
# >* Добавляет данные о покупках в профили.
# >* Рассчитывает лайфтайм для каждой покупки.
# >* Группирует данные по указанным измерениям (dimensions) и вычисляет конверсию для каждой когорты.
# >* Возвращает "сырые" данные, агрегированную таблицу конверсии и таблицу динамики конверсии во времени.
# >
# >Эта функция позволит изучить конверсию пользователей в разрезе различных измерений, таких как источник трафика, устройство и др.

# %% [markdown]
# **Функция `get_ltv()`:**

# %%
# функция для расчёта LTV и ROI

def get_ltv(
    profiles,
    purchases,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    # исключаем пользователей, не «доживших» до горизонта анализа
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')
    # добавляем данные о покупках в профили
    result_raw = result_raw.merge(
        purchases[['user_id', 'event_dt', 'revenue']], on='user_id', how='left'
    )
    # рассчитываем лайфтайм пользователя для каждой покупки
    result_raw['lifetime'] = (
        result_raw['event_dt'] - result_raw['first_ts']
    ).dt.days
    # группируем по cohort, если в dimensions ничего нет
    if len(dimensions) == 0:
        result_raw['cohort'] = 'All users'
        dimensions = dimensions + ['cohort']

    # функция группировки по желаемым признакам
    def group_by_dimensions(df, dims, horizon_days):
        # строим «треугольную» таблицу выручки
        result = df.pivot_table(
            index=dims, columns='lifetime', values='revenue', aggfunc='sum'
        )
        # находим сумму выручки с накоплением
        result = result.fillna(0).cumsum(axis=1)
        # вычисляем размеры когорт
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        # объединяем размеры когорт и таблицу выручки
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        # считаем LTV: делим каждую «ячейку» в строке на размер когорты
        result = result.div(result['cohort_size'], axis=0)
        # исключаем все лайфтаймы, превышающие горизонт анализа
        result = result[['cohort_size'] + list(range(horizon_days))]
        # восстанавливаем размеры когорт
        result['cohort_size'] = cohort_sizes

        # собираем датафрейм с данными пользователей и значениями CAC, 
        # добавляя параметры из dimensions
        cac = df[['user_id', 'acquisition_cost'] + dims].drop_duplicates()

        # считаем средний CAC по параметрам из dimensions
        cac = (
            cac.groupby(dims)
            .agg({'acquisition_cost': 'mean'})
            .rename(columns={'acquisition_cost': 'cac'})
        )

        # считаем ROI: делим LTV на CAC
        roi = result.div(cac['cac'], axis=0)

        # удаляем строки с бесконечным ROI
        roi = roi[~roi['cohort_size'].isin([np.inf])]

        # восстанавливаем размеры когорт в таблице ROI
        roi['cohort_size'] = cohort_sizes

        # добавляем CAC в таблицу ROI
        roi['cac'] = cac['cac']

        # в финальной таблице оставляем размеры когорт, CAC
        # и ROI в лайфтаймы, не превышающие горизонт анализа
        roi = roi[['cohort_size', 'cac'] + list(range(horizon_days))]

        # возвращаем таблицы LTV и ROI
        return result, roi

    # получаем таблицы LTV и ROI
    result_grouped, roi_grouped = group_by_dimensions(
        result_raw, dimensions, horizon_days
    )

    # для таблиц динамики убираем 'cohort' из dimensions
    if 'cohort' in dimensions:
        dimensions = []

    # получаем таблицы динамики LTV и ROI
    result_in_time, roi_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    return (
        result_raw,  # сырые данные
        result_grouped,  # таблица LTV
        result_in_time,  # таблица динамики LTV
        roi_grouped,  # таблица ROI
        roi_in_time,  # таблица динамики ROI
    )

# %% [markdown]
# >Функция рассчитывает LTV (Life-Time Value) и ROI (Return on Investment) пользователей.
# >
# >Основные шаги, выполняемые этой функцией:
# >* Исключает пользователей, которые не "дожили" до горизонта анализа.
# >* Добавляет данные о покупках в профили.
# >* Рассчитывает лайфтайм пользователя для каждой покупки.
# >* Группирует данные по указанным измерениям (dimensions) и вычисляет LTV для каждой когорты.
# >* Рассчитывает ROI, деля LTV на CAC (Cost of Acquisition per Customer).
# >* Возвращает "сырые" данные, агрегированную таблицу LTV, таблицу динамики LTV, таблицу ROI и таблицу динамики ROI.
# >
# >Эта функция позволит изучить LTV и ROI пользователей в разрезе различных измерений, таких как источник трафика, устройство и др.

# %% [markdown]
# **Функция `filter_data()`:**

# %%
# функция для сглаживания фрейма

def filter_data(df, window):
    # для каждого столбца применяем скользящее среднее
    for column in df.columns.values:
        df[column] = df[column].rolling(window).mean() 
    return df

# %% [markdown]
# >Функция применяет скользящее среднее к каждому столбцу в переданном dataframe.
# >Эта функция помогает сгладить данные, делая их менее подверженными краткосрочным колебаниям и шуму, что особенно полезно при визуализации временных рядов.
# >
# >Функция принимает на вход:
# >
# >* __df__: dataframe, к которому следует применить скользящее среднее.
# >* __window__: размер окна для скользящего среднего.
# >
# >После применения этой функции к данным, графики станут более плавными и легче интерпретируемыми.

# %% [markdown]
# **Функция `plot_retention()`:**

# %%
# функция для визуализации удержания

def plot_retention(retention, retention_history, horizon, window=7):

    # задаём размер сетки для графиков
    plt.figure(figsize=(15, 10))

    # исключаем размеры когорт и удержание первого дня
    retention = retention.drop(columns=['cohort_size', 0])
    # в таблице динамики оставляем только нужный лайфтайм
    retention_history = retention_history.drop(columns=['cohort_size'])[
        [horizon - 1]
    ]

    # если в индексах таблицы удержания только payer,
    # добавляем второй признак — cohort
    if retention.index.nlevels == 1:
        retention['cohort'] = 'All users'
        retention = retention.reset_index().set_index(['cohort', 'payer'])

    # в таблице графиков — два столбца и две строки, четыре ячейки
    # в первой строим кривые удержания платящих пользователей
    ax1 = plt.subplot(2, 2, 1)
    retention.query('payer == True').droplevel('payer').T.plot(
        grid=True, ax=ax1
    )
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Удержание платящих пользователей')

    # во второй ячейке строим кривые удержания неплатящих
    # вертикальная ось — от графика из первой ячейки
    ax2 = plt.subplot(2, 2, 2, sharey=ax1)
    retention.query('payer == False').droplevel('payer').T.plot(
        grid=True, ax=ax2
    )
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Удержание неплатящих пользователей')

    # в третьей ячейке — динамика удержания платящих
    ax3 = plt.subplot(2, 2, 3)
    # получаем названия столбцов для сводной таблицы
    columns = [
        name
        for name in retention_history.index.names
        if name not in ['dt', 'payer']
    ]
    # фильтруем данные и строим график
    filtered_data = retention_history.query('payer == True').pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax3)
    plt.xlabel('Дата привлечения')
    plt.title(
        'Динамика удержания платящих пользователей на {}-й день'.format(
            horizon
        )
    )

    # в чётвертой ячейке — динамика удержания неплатящих
    ax4 = plt.subplot(2, 2, 4, sharey=ax3)
    # фильтруем данные и строим график
    filtered_data = retention_history.query('payer == False').pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax4)
    plt.xlabel('Дата привлечения')
    plt.title(
        'Динамика удержания неплатящих пользователей на {}-й день'.format(
            horizon
        )
    )
    
    plt.tight_layout()
    plt.show()

# %% [markdown]
# >Функция визуализирует коэффициент удержания (Retention Rate) для платящих и неплатящих пользователей.
# >
# >В этой функции:
# >
# >* Исключается размер когорты и удержание на первый день.
# >* Строятся графики кривых удержания для платящих и неплатящих пользователей.
# >* Визуализируется динамика удержания для платящих и неплатящих пользователей на конкретный день (например, на 7-й день после регистрации).
# >
# >Эта функция позволит наглядно увидеть, как удержание изменяется с течением времени для разных когорт пользователей, и сравнить удержание платящих и неплатящих пользователей.

# %% [markdown]
# **Функция `plot_conversion()`:**

# %%
# функция для визуализации конверсии

def plot_conversion(conversion, conversion_history, horizon, window=7):

    # задаём размер сетки для графиков
    plt.figure(figsize=(15, 5))

    # исключаем размеры когорт
    conversion = conversion.drop(columns=['cohort_size'])
    # в таблице динамики оставляем только нужный лайфтайм
    conversion_history = conversion_history.drop(columns=['cohort_size'])[
        [horizon - 1]
    ]

    # первый график — кривые конверсии
    ax1 = plt.subplot(1, 2, 1)
    conversion.T.plot(grid=True, ax=ax1)
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Конверсия пользователей')

    # второй график — динамика конверсии
    ax2 = plt.subplot(1, 2, 2, sharey=ax1)
    columns = [
        # столбцами сводной таблицы станут все столбцы индекса, кроме даты
        name for name in conversion_history.index.names if name not in ['dt']
    ]
    filtered_data = conversion_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax2)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика конверсии пользователей на {}-й день'.format(horizon))

    plt.tight_layout()
    plt.show()

# %% [markdown]
# >Функция визуализирует конверсию пользователей.
# >
# >В этой функции:
# >
# >* Исключается размер когорты из данных.
# >* Строится график кривых конверсии для разных когорт пользователей.
# >* Визуализируется динамика конверсии для пользователей на определенный день (например, на 7-й день после регистрации).
# >
# >
# >Это полезно для понимания, какая доля новых пользователей совершает покупку в течение определенного временного интервала после их первого взаимодействия с продуктом.

# %% [markdown]
# **Функция `plot_ltv_roi`:**

# %%
# функция для визуализации LTV и ROI

def plot_ltv_roi(ltv, ltv_history, roi, roi_history, horizon, window=7):

    # задаём сетку отрисовки графиков
    plt.figure(figsize=(20, 10))

    # из таблицы ltv исключаем размеры когорт
    ltv = ltv.drop(columns=['cohort_size'])
    # в таблице динамики ltv оставляем только нужный лайфтайм
    ltv_history = ltv_history.drop(columns=['cohort_size'])[[horizon - 1]]

    # стоимость привлечения запишем в отдельный фрейм
    cac_history = roi_history[['cac']]

    # из таблицы roi исключаем размеры когорт и cac
    roi = roi.drop(columns=['cohort_size', 'cac'])
    # в таблице динамики roi оставляем только нужный лайфтайм
    roi_history = roi_history.drop(columns=['cohort_size', 'cac'])[
        [horizon - 1]
    ]

    # первый график — кривые ltv
    ax1 = plt.subplot(2, 3, 1)
    ltv.T.plot(grid=True, ax=ax1)
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('LTV')

    # второй график — динамика ltv
    ax2 = plt.subplot(2, 3, 2, sharey=ax1)
    # столбцами сводной таблицы станут все столбцы индекса, кроме даты
    columns = [name for name in ltv_history.index.names if name not in ['dt']]
    filtered_data = ltv_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax2)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика LTV пользователей на {}-й день'.format(horizon))

    # третий график — динамика cac
    ax3 = plt.subplot(2, 3, 3, sharey=ax1)
    # столбцами сводной таблицы станут все столбцы индекса, кроме даты
    columns = [name for name in cac_history.index.names if name not in ['dt']]
    filtered_data = cac_history.pivot_table(
        index='dt', columns=columns, values='cac', aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax3)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика стоимости привлечения пользователей')

    # четвёртый график — кривые roi
    ax4 = plt.subplot(2, 3, 4)
    roi.T.plot(grid=True, ax=ax4)
    plt.axhline(y=1, color='red', linestyle='--', label='Уровень окупаемости')
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('ROI')

    # пятый график — динамика roi
    ax5 = plt.subplot(2, 3, 5, sharey=ax4)
    # столбцами сводной таблицы станут все столбцы индекса, кроме даты
    columns = [name for name in roi_history.index.names if name not in ['dt']]
    filtered_data = roi_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax5)
    plt.axhline(y=1, color='red', linestyle='--', label='Уровень окупаемости')
    plt.xlabel('Дата привлечения')
    plt.title('Динамика ROI пользователей на {}-й день'.format(horizon))

    plt.tight_layout()
    plt.show()

# %% [markdown]
# >Функция визуализирует LTV (Lifetime Value) и ROI (Return On Investment) пользователей.
# >
# >В этой функции:
# >
# >* Подготавливаются данные для визуализации, исключая необходимые столбцы и оставляя только интересующий временной горизонт.
# >* Строятся графики LTV по когортам и его динамика во времени.
# >* Визуализируется динамика стоимости привлечения пользователей (CAC).
# >* Строятся графики ROI по когортам и его динамика во времени, с учетом уровня окупаемости.
# >
# >Это полезно для понимания, сколько денег приносит каждый привлеченный пользователь в течение определенного временного интервала, и как быстро вкладывания в привлечение окупаются.

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Хорошо, все необходимые функции были заданы, можно приступать к расчета и анализу👀

# %% [markdown]
# ### Исследовательский анализ данных
#
# - Составьте профили пользователей. Определите минимальную и максимальную даты привлечения пользователей.
# - Выясните, из каких стран пользователи приходят в приложение и на какую страну приходится больше всего платящих пользователей. Постройте таблицу, отражающую количество пользователей и долю платящих из каждой страны.
# - Узнайте, какими устройствами пользуются клиенты и какие устройства предпочитают платящие пользователи. Постройте таблицу, отражающую количество пользователей и долю платящих для каждого устройства.
# - Изучите рекламные источники привлечения и определите каналы, из которых пришло больше всего платящих пользователей. Постройте таблицу, отражающую количество пользователей и долю платящих для каждого канала привлечения.
#
# После каждого пункта сформулируйте выводы.

# %% [markdown]
# **Профили пользователей: определение минимальной и максимальной дат привлечения пользователей:**

# %% [markdown]
# Вызовем функцию `get_profiles()`, чтобы составить профили пользователей по данным сессий из датафрейма `visits_info`:

# %%
profiles = get_profiles(visits_info, orders_info, costs_info)
display(profiles.head())
# Out:
#     user_id            first_ts     channel  device         region  \
# 0    599326 2019-05-07 20:58:57    FaceBoom     Mac  United States
# 1   4919697 2019-07-09 12:46:07    FaceBoom  iPhone  United States
# 2   6085896 2019-10-01 09:58:33     organic  iPhone         France
# 3  22593348 2019-08-22 21:35:48  AdNonSense      PC        Germany
# 4  31989216 2019-10-02 00:07:44     YRabbit  iPhone  United States
#
#            dt      month  payer  acquisition_cost
# 0  2019-05-07 2019-05-01   True          1.088172
# 1  2019-07-09 2019-07-01  False          1.107237
# 2  2019-10-01 2019-10-01  False          0.000000
# 3  2019-08-22 2019-08-01  False          0.988235
# 4  2019-10-02 2019-10-01  False          0.230769

# %%
profiles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 150008 entries, 0 to 150007
# Data columns (total 9 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   user_id           150008 non-null  int64
#  1   first_ts          150008 non-null  datetime64[ns]
#  2   channel           150008 non-null  object
#  3   device            150008 non-null  object
#  4   region            150008 non-null  object
#  5   dt                150008 non-null  object
#  6   month             150008 non-null  datetime64[ns]
#  7   payer             150008 non-null  bool
#  8   acquisition_cost  150008 non-null  float64
# dtypes: bool(1), datetime64[ns](2), float64(1), int64(1), object(4)
# memory usage: 10.4+ MB

# %%
# Определим минимальную и максимальную дату привлечения пользователей.

min_date = profiles['first_ts'].min()
max_date = profiles['first_ts'].max()
print(f'Минимальная дата привлечения пользоваелей: {min_date}')  
print()
print(f'Максимальная дата привлечения пользоваелей: {max_date}')
# Out:
# Минимальная дата привлечения пользоваелей: 2019-05-01 00:00:41
#
# Максимальная дата привлечения пользоваелей: 2019-10-27 23:59:04

# %% [markdown]
# >150008 пользовательских профилей за период с 01 мая по 27 октября 2019 года, в каждом из которых есть данные о дате первого посещения и рекламном источнике, который мотивировал пользователя воспользоваться приложением Procrastinate Pro+. Такие данные значительно упрощают дальнейший анализ.

# %% [markdown]
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №1__
#
# Неплохо бы проверить даты на соответствие ТЗ
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарии студента:</b> Проверил даты на соответствие ТЗ.</div>

# %%
# Расчет минимальной и максимальной дат привлечения пользователей
min_date = visits_info['session_start'].min()
max_date = visits_info['session_start'].max()

min_date, max_date
# Out:
# (Timestamp('2019-05-01 00:00:41'), Timestamp('2019-10-31 23:59:23'))

# %% [markdown]
# **Минимальная дата привлечения пользователей:** 1 мая 2019 года, 00:00:41.
#
# **Максимальная дата привлечения пользователей:** 31 октября 2019 года, 23:59:23.
#
# Данные охватывают период с 1 мая 2019 года по 31 октября 2019 года, что соответствует условиям проекта (шести месяцам).
# Таким образом, данные соответствуют ТЗ.

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №2__
#
# Все верно!👍

# %%
# Общее количество пользователей по странам
users_by_country = visits_info.groupby('region').agg(total_users=('user_id', 'nunique'))

# Платящие пользователи по странам
paying_users_by_country = orders_info.merge(visits_info, on='user_id').groupby('region')\
.agg(paying_users=('user_id', 'nunique'))

# Объединение двух фреймов данных
country_data = users_by_country.merge(paying_users_by_country, left_index=True, right_index=True, how='left').fillna(0)

# Подсчет доли платящих пользователей
country_data['share_paying'] = (country_data['paying_users'] / country_data['total_users'] * 100).round(2).astype(str) + '%'

country_data = country_data.sort_values(by='paying_users', ascending=False)

country_data
# Out:
#                total_users  paying_users share_paying
# region
# United States       100002          6902         6.9%
# UK                   17575           700        3.98%
# France               17450           663         3.8%
# Germany              14981           616        4.11%

# %% [markdown]
# **Выясним, из каких стран пользователи приходят в приложение и на какую страну приходится больше всего платящих пользователей.**
# **Построим таблицу, отражающую количество пользователей и долю платящих из каждой страны.**

# %% [markdown]
# **Построим таблицу, отражающую количество пользователей и долю платящих из каждой страны.**

# %% [markdown]
# Чтобы ответить на вопрос, выполним следующие шаги:
#
# * Исследуем уникальные значения стран в датафрейме `visits_info`.
# * Сгруппируем данные по странам и посчитаем количество уникальных пользователей в каждой стране.
# * Определим платящих пользователей, связав данные из `visits_info` и `orders_info` по `user_id`.
# * Сгруппируем данные о платящих пользователях по странам и посчитаем их количество.
# * Объединим данные о всех пользователях и платящих пользователях, чтобы рассчитать долю платящих пользователей в каждой стране.

# %% [markdown]
# Начнем с исследования уникальных значений стран в датафрейме `visits_info`:

# %%
# Проверка уникальных стран в датафрейме `visits_info`
unique_countries = visits_info['region'].unique()
unique_countries
# Out:
# array(['United States', 'UK', 'France', 'Germany'], dtype=object)

# %% [markdown]
# >Пользователи приходят в приложение из следующих стран:
# >
# >* Соединенные Штаты Америки (United States)
# >* Великобритания (UK)
# >* Франция (France)
# >* Германия (Germany)

# %% [markdown]
# Теперь определим общее количество пользователей и количество платящих пользователей из каждой из этих стран:

# %%
# Подсчет общего количества пользователей из каждой страны
total_users_by_country = visits_info.groupby('region')['user_id'].nunique().reset_index()

# Определение платящих пользователей путем объединения наборов данных visits_info и orders_info
paying_users = visits_info.merge(orders_info, on='user_id', how='inner').drop_duplicates(subset='user_id')


# Подсчет платящих пользователей из каждой страны
paying_users_by_country = paying_users.groupby('region')['user_id'].nunique().reset_index()

# Объединение данных об общем количестве пользователей и платящих пользователей
country_stats = total_users_by_country.merge(paying_users_by_country, on='region', how='left', 
                                             suffixes=('_total', '_paying'))

# Подсчет доли платящих пользователей
country_stats['paying_proportion'] = (country_stats['user_id_paying'] / country_stats['user_id_total']*100)\
.round(2).astype(str) + '%'

country_stats.columns = ['Страна', 'Общее количество пользователей', 'Количество платящих пользователей',\
                      'Доля платящих пользователей']
# country_stats['Доля платящих пользователей'] = (country_stats['Доля платящих пользователей'] * 100).round(2).astype(str) + '%'
country_stats
# Out:
#           Страна  Общее количество пользователей  \
# 0         France                           17450
# 1        Germany                           14981
# 2             UK                           17575
# 3  United States                          100002
#
#    Количество платящих пользователей Доля платящих пользователей
# 0                                663                        3.8%
# 1                                616                       4.11%
# 2                                700                       3.98%
# 3                               6902                        6.9%

# %% [markdown]
# **Построим график, отражающий количество пользователей и долю платящих из каждой страны:**

# %% [markdown]
# Для наглядного отображения данных, построим два графика:
#
# * Столбчатый график для отображения общего количества пользователей и платящих пользователей из каждой страны.
# * График типа "ломаная линия" для отображения доли платящих пользователей из каждой страны.

# %%
total_users_by_country = visits_info.groupby('region')['user_id'].nunique().reset_index()
paying_users = visits_info.merge(orders_info, on='user_id', how='inner').drop_duplicates(subset='user_id')
paying_users_by_country = paying_users.groupby('region')['user_id'].nunique().reset_index()
country_stats_snake_case = total_users_by_country.merge(paying_users_by_country, on='region', how='left', 
                                                        suffixes=('_total', '_paying'))
country_stats_snake_case['paying_proportion'] = (country_stats_snake_case['user_id_paying'] / \
                                                 country_stats_snake_case['user_id_total'] * 100).round(2).astype(str) + '%'

country_stats_snake_case.columns = ['Страна', 'Общее количество пользователей', 'Количество платящих пользователей',\
                                    'Доля платящих пользователей']

# Установка индекса и построение графика
country_data = country_stats_snake_case.set_index('Страна')

fig, ax1 = plt.subplots(figsize=(12, 10))

# Гистограмма для общего числа пользователей
sns.barplot(x=country_data.index, y=country_data['Общее количество пользователей'], ax=ax1, \
            palette="viridis", alpha=0.6, label='Общее количество пользователей')

# Гистограмма для платящих пользователей красного цвета
sns.barplot(x=country_data.index, y=country_data['Количество платящих пользователей'], ax=ax1, color="red",\
            alpha=0.6, label='Количество платящих пользователей')

ax1.set_title('Общее количество, количество платящих и доля платящих пользователей по странам', fontsize=15)
ax1.set_ylabel('Количество пользователей', fontsize=12)
ax1.set_xlabel('Страны', fontsize=12)

# Настройка вторичной оси для процентов
ax2 = ax1.twinx()
sns.lineplot(x=country_data.index, y=country_data['Доля платящих пользователей'].str.rstrip('%').astype(float),\
             color='blue', marker="o", ax=ax2, label='Процент платящих пользователей')
ax2.set_ylabel('Процент платящих пользователей (%)', fontsize=12)

# Отображение легенды
ax1.legend(loc='upper left')
ax2.legend(loc='upper right')

plt.tight_layout()
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
#
# Молодец, что визуализируешь полученные данные. Это важный скилл для аналитика. Развивай его

# %% [markdown]
# >* United States (США): из 100,002 пользователей, 6,902 (или 6.9%) совершили покупку.
# >
# >* UK (Великобритания): из 17,575 пользователей, 700 (или 3.98%) совершили покупку.
# >
# >* France (Франция): из 17,450 пользователей, 663 (или 3.8%) совершили покупку.
# >
# >* Germany (Германия): из 14,981 пользователя, 616 (или 4.11%) совершили покупку.

# %% [markdown]
# На основе проведенного анализа и визуализации данных можно сделать следующие выводы:
#
# >* Распределение пользователей по странам: Соединенные Штаты Америки являются основным источником трафика, с более чем 100,000 пользователей. Они значительно опережают другие страны в этом списке.
# >
# >* Платящие пользователи: Несмотря на то что США имеют наибольшее абсолютное количество платящих пользователей (6,902 пользователей), относительно других стран, США также имеют наивысшую долю платящих пользователей, составляющую около 6.90%.
# >
# >* Другие страны: Великобритания, Франция и Германия имеют схожее количество пользователей (около 15,000-17,500). Однако доля платящих пользователей в этих странах колеблется в пределах 3.8% - 4.1%.

# %% [markdown]
# **Узнаем, какими устройствами пользуются клиенты и какие устройства предпочитают платящие пользователи.
# Построим таблицу, отражающую количество пользователей и долю платящих для каждого устройства:**

# %% [markdown]
# Для этого:
#
# * Посчитаем общее количество пользователей для каждого устройства.
# * Определим платящих пользователей для каждого устройства.
# * Рассчитаем долю платящих пользователей для каждого устройства.

# %%
# Подсчет общего количества пользователей по устройствам
total_users_by_device = visits_info.groupby('device')['user_id'].nunique().reset_index()

# Подсчет платящих пользователей по устройствам
paying_users_by_device = paying_users.groupby('device')['user_id'].nunique().reset_index()

# Объединение общего количества пользователей и данных платящих пользователей по устройствам
device_stats = total_users_by_device.merge(paying_users_by_device, on='device', how='left', 
                                           suffixes=('_total', '_paying'))

# Расчет доли платящих пользователей по устройствам
device_stats['paying_proportion'] = (device_stats['user_id_paying'] / device_stats['user_id_total'] * 100)\
.round(2).astype(str) + '%'

device_stats.columns = ['Устройство', 'Общее количество пользователей', 'Количество платящих пользователей',\
                        'Доля платящих пользователей']

device_stats
# Out:
#   Устройство  Общее количество пользователей  \
# 0    Android                           36377
# 1        Mac                           31335
# 2         PC                           31681
# 3     iPhone                           55798
#
#    Количество платящих пользователей Доля платящих пользователей
# 0                               2050                       5.64%
# 1                               1912                        6.1%
# 2                               1537                       4.85%
# 3                               3382                       6.06%

# %% [markdown]
# >Как видно из таблицы, большинство пользователей предпочитают iPhone.
# >Доля платящих пользователей на Mac и iPhone примерно одинакова и составляет около 6%.
# >На Android и PC доля платящих пользователей ниже — около 5-6%.

# %%
fig, ax1 = plt.subplots(figsize=(12, 10))

# Гистограмма для общего числа пользователей
sns.barplot(x=device_stats['Устройство'], y=device_stats['Общее количество пользователей'], ax=ax1,\
            palette="viridis", alpha=0.6, label='Общее количество пользователей')

# Гистограмма для платящих пользователей красного цвета
sns.barplot(x=device_stats['Устройство'], y=device_stats['Количество платящих пользователей'], ax=ax1, color="red",\
            alpha=0.6, label='Количество платящих пользователей')

ax1.set_title('Общее количество, количество платящих и доля платящих пользователей по устройствам', fontsize=15)
ax1.set_ylabel('Количество пользователей', fontsize=12)
ax1.set_xlabel('Устройства', fontsize=12)

# Настройка вторичной оси для процентов
ax2 = ax1.twinx()
sns.lineplot(x=device_stats['Устройство'], y=device_stats['Доля платящих пользователей'].str.rstrip('%').astype(float),\
             color='blue', marker="o", ax=ax2, label='Процент платящих пользователей')
ax2.set_ylabel('Процент платящих пользователей (%)', fontsize=12)

# Отображение легенды
ax1.legend(loc='upper left')
ax2.legend(loc='upper right')

plt.tight_layout()
plt.show()

# %% [markdown]
# Как видно из графика:
#
# Большинство пользователей использует iPhone.
# Процент платящих пользователей выше для устройств iPhone и Mac, в то время как для Android и PC он немного ниже.

# %% [markdown]
# Вывод:
#
# >* iPhone является наиболее популярным устройством среди пользователей, с самым большим общим количеством пользователей.
# >Это делает его ключевым устройством для привлечения и взаимодействия с клиентами.
# >* Однако, несмотря на высокое общее количество пользователей iPhone,
# >процент платящих пользователей на Mac и iPhone примерно одинаков и составляет около 6%.
# >Это указывает на то, что пользователи Apple (Mac и iPhone) имеют более высокую вероятность совершения покупок.
# >* Устройства на базе Android и PC имеют немного меньший процент платящих пользователей, около 5-6%. Это может указывать на необходимость оптимизации пользовательского опыта или маркетинговых стратегий для этих платформ.

# %% [markdown]
# **Изучим рекламные источники привлечения и определим каналы, из которых пришло больше всего платящих пользователей.
# Построим таблицу, отражающую количество пользователей и долю платящих для каждого канала привлечения.**

# %% [markdown]
# Для этого:
#
# * Посчитаем общее количество пользователей для каждого рекламного канала.
# * Определим платящих пользователей для каждого рекламного канала.
# * Рассчитаем долю платящих пользователей для каждого рекламного канала.

# %%
# Подсчет общего количества пользователей по каналам
total_users_by_channel = visits_info.groupby('channel')['user_id'].nunique().reset_index()

# Подсчет платящих пользователей по каналам
paying_users_by_channel = paying_users.groupby('channel')['user_id'].nunique().reset_index()

# Объединение общего количества пользователей и данных платящих пользователей по каналам
channel_stats = total_users_by_channel.merge(paying_users_by_channel, on='channel', how='left', 
                                             suffixes=('_total', '_paying'))

# Расчет доли платящих пользователей по каналам
channel_stats['paying_proportion'] = (channel_stats['user_id_paying'] / channel_stats['user_id_total'] * 100).round(2).astype(str) + '%'

channel_stats.columns = ['Рекламный канал', 'Общее количество пользователей', 'Количество платящих пользователей', 'Доля платящих пользователей']

channel_stats.sort_values(by='Количество платящих пользователей', ascending=False)
# Out:
#        Рекламный канал  Общее количество пользователей  \
# 1             FaceBoom                           29916
# 6               TipTop                           20204
# 10             organic                           57673
# 7       WahooNetBanner                            8845
# 0           AdNonSense                            4199
# 5       RocketSuperAds                            4988
# 2              LeapBob                            8875
# 4   OppleCreativeMedia                            8929
# 9       lambdaMediaAds                            2410
# 8              YRabbit                            4882
# 3         MediaTornado                            4895
#
#     Количество платящих пользователей Доля платящих пользователей
# 1                                3557                      11.89%
# 6                                1878                        9.3%
# 10                               1160                       2.01%
# ...

# %% [markdown]
# __FaceBoom__ является самым эффективным каналом, привлекая наибольшее количество платящих пользователей,
# а также имея высокую долю платящих пользователей (почти 12%).
# __TipTop__ также является довольно эффективным каналом, с долей платящих пользователей более 9%.
# Хотя __organic__ привлекает большое количество пользователей, его доля платящих пользователей значительно ниже, чем у других каналов.

# %%
# Sorting the data by total number of users in descending order for plotting
sorted_channel_stats = channel_stats.sort_values(by='Общее количество пользователей', ascending=False)

# Plotting the data for advertising channels
fig, ax1 = plt.subplots(figsize=(14, 10))

# Bar plot for total users
sns.barplot(x=sorted_channel_stats['Рекламный канал'], y=sorted_channel_stats['Общее количество пользователей'], ax=ax1, palette="viridis", alpha=0.6, label='Общее количество пользователей')

# Bar plot for paying users with red color
sns.barplot(x=sorted_channel_stats['Рекламный канал'], y=sorted_channel_stats['Количество платящих пользователей'], ax=ax1, color="red", alpha=0.6, label='Количество платящих пользователей')

ax1.set_title('Общее количество, количество платящих и доля платящих пользователей по рекламным каналам', fontsize=15)
ax1.set_ylabel('Количество пользователей', fontsize=12)
ax1.set_xlabel('Рекламные каналы', fontsize=12)
plt.xticks(rotation=45)
# Setting up the secondary axis for percentages
ax2 = ax1.twinx()
sns.lineplot(x=sorted_channel_stats['Рекламный канал'], y=sorted_channel_stats['Доля платящих пользователей'].str.rstrip('%').astype(float), color='blue', marker="o", ax=ax2, label='Процент платящих пользователей')
ax2.set_ylabel('Процент платящих пользователей (%)', fontsize=12)

# Displaying the legend
ax1.legend(loc='upper left')
ax2.legend(loc='upper right')

plt.tight_layout()
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# Вывод:
#
# FaceBoom является наиболее эффективным рекламным каналом:
# * Привлекает наибольшее количество платящих пользователей.
# * Имеет высокую долю платящих пользователей, приближающуюся к 12%.
#
# TipTop также показывает хорошие результаты:
# * Привлекает значительное количество платящих пользователей.
# * Доля платящих пользователей составляет более 9%.
# Несмотря на то что organic привлекает большое общее количество пользователей, его доля платящих пользователей существенно ниже (около 2%). Это может указывать на необходимость оптимизации стратегии привлечения для этого канала или рассмотрения специфики привлекаемой аудитории.
#
# Для максимизации ROI (возврата на инвестиции в рекламу) рекомендуется увеличить инвестиции в каналы FaceBoom и TipTop, так как они привлекают наибольший процент платящих пользователей.

# %% [markdown]
# **Общий вывод:**
#
# 1. По странам:
#     * США привлекает наибольшее количество пользователей, а также имеет наибольшее количество платящих пользователей.
#     * Относительно других стран, США также имеет высокую долю платящих пользователей (почти 7%).
#
#
# 2. По устройствам:
#     * Большинство пользователей предпочитают использовать смартфоны (Android и iPhone) для доступа к приложению.
#     * Пользователи, использующие iPad, имеют самую высокую долю платящих пользователей, хотя их общее количество меньше по сравнению с пользователями смартфонов.
#
#
# 3. По рекламным каналам:
#     * FaceBoom является наиболее эффективным рекламным каналом, привлекая наибольшее количество платящих пользователей и имея долю платящих пользователей почти 12%.
#     * Несмотря на то что organic привлекает наибольшее общее количество пользователей, его доля платящих пользователей значительно меньше, чем у платных каналов.
#
#
# Рекомендации:
#
# Усилить рекламные кампании в США, учитывая их высокую долю платящих пользователей.
# Оптимизировать приложение для iPad, так как эта платформа имеет высокий потенциал конверсии в платящих пользователей.
# Увеличить инвестиции в рекламный канал FaceBoom и возможно пересмотреть стратегию привлечения для канала organic.

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
#
# В целом в данном разделе был проведен хороший анализ данных - мы посмотрели на базовые значения конверсии пользователей в покупатели по регионам, устройствам и каналу привлечения, определили основной рынок. Получается, что больше всего приходит пользователей из США и они лучше других конвертируется. При этом большая часть пользователей заходит с мобильных устройств, это тоже стоит отметить. Также, мы можем сказать, что наибольшую конверсию имеют пользователи, которые пользуются Mac, а затем следуют пользователи iPhone, т.е. мы можем сказать, что в целом пользователи Apple имеют лучшую конверсию в покупателей. Возможно, тут есть плюсы ApplePay.

# %% [markdown]
# ### Маркетинг
#
# - Посчитайте общую сумму расходов на маркетинг.
# - Выясните, как траты распределены по рекламным источникам, то есть сколько денег потратили на каждый источник.
# - Постройте визуализацию динамики изменения расходов во времени (по неделям и месяцам) по каждому источнику. Постарайтесь отразить это на одном графике.
# - Узнайте, сколько в среднем стоило привлечение одного пользователя (CAC) из каждого источника. Используйте профили пользователей.
#
# Напишите промежуточные выводы.

# %% [markdown]
# **Посчитаем общую сумму расходов на маркетинг:**

# %%
# Общие затраты на маркетинг
total_marketing_costs = costs_info['costs'].sum().round(2)
total_marketing_costs
# Out:
# 105497.3

# %% [markdown]
# >Общая сумма расходов на маркетинг составляет 105,497.30 у.е.

# %% [markdown]
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №1__
#
# Лучше округлить до 1-2 знаков, после запятой
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарии студента:</b> Исправил!</div>

# %% [markdown]
# **Выясним, как траты распределены по рекламным источникам, то есть сколько денег потратили на каждый источник:**

# %%
# Сумма маркетинговых затрат на каждый рекламный канал
costs_per_channel_corrected = costs_info.groupby('channel')['costs'].sum().sort_values(ascending=False).reset_index()
costs_per_channel_corrected
# Out:
#               channel     costs
# 0              TipTop  54751.30
# 1            FaceBoom  32445.60
# 2      WahooNetBanner   5151.00
# 3          AdNonSense   3911.25
# 4  OppleCreativeMedia   2151.25
# 5      RocketSuperAds   1833.00
# 6             LeapBob   1797.60
# 7      lambdaMediaAds   1557.60
# 8        MediaTornado    954.48
# 9             YRabbit    944.22

# %% [markdown]
# >Лидерами по расходам на маркетинг, с большим отрывом, стали основные поставщики рекламного траффика: FaceBoom и TipTop

# %% [markdown]
# **Построим визуализацию динамики изменения расходов во времени (по неделям и месяцам) по каждому источнику.
# Отразим визуализацию на одном графике:**

# %%
# Добавим в датафрейм столбцы недель и месяцев
costs_info['month'] = pd.to_datetime(costs_info['dt']).dt.month
costs_info['week'] = pd.to_datetime(costs_info['dt']).dt.isocalendar().week
costs_info.head()
# Out:
#            dt   channel  costs  month  week
# 0  2019-05-01  FaceBoom  113.3      5    18
# 1  2019-05-02  FaceBoom   78.1      5    18
# 2  2019-05-03  FaceBoom   85.8      5    18
# 3  2019-05-04  FaceBoom  136.4      5    18
# 4  2019-05-05  FaceBoom  122.1      5    18

# %%
# Группировка данных по неделям и месяцам
weekly_costs = costs_info.groupby(['week', 'channel'])['costs'].sum().reset_index()
monthly_costs = costs_info.groupby(['month', 'channel'])['costs'].sum().reset_index()

# Преобразование данных типа "period" в строковый формат
weekly_costs['week'] = weekly_costs['week'].astype(str)
monthly_costs['month'] = monthly_costs['month'].astype(str)

# Создание фигуры для двух графиков
fig, axes = plt.subplots(nrows=2, ncols=1, figsize=(15, 12))

# График для недельных данных
for channel in weekly_costs['channel'].unique():
    sns.lineplot(data=weekly_costs[weekly_costs['channel'] == channel], 
                 x='week', y='costs', label=channel, ax=axes[0])
axes[0].set_title('Динамика изменения расходов по источникам (по неделям)')
axes[0].set_xlabel('Неделя')
axes[0].set_ylabel('Расходы')
axes[0].legend()
axes[0].tick_params(axis='x', rotation=45)
axes[0].grid(True, which='both', linestyle='--', linewidth=0.5)

# График для месячных данных
for channel in monthly_costs['channel'].unique():
    sns.lineplot(data=monthly_costs[monthly_costs['channel'] == channel], 
                 x='month', y='costs', label=channel, ax=axes[1])
axes[1].set_title('Динамика изменения расходов по источникам (по месяцам)')
axes[1].set_xlabel('Месяц')
axes[1].set_ylabel('Расходы')
axes[1].legend()
axes[1].tick_params(axis='x', rotation=45)
axes[1].grid(True, which='both', linestyle='--', linewidth=0.5)

# Автоматическое распределение места между графиками
plt.tight_layout()
plt.show()

# %% [markdown]
# >Вывод на основе визуализации:
# >
# >* __Расходы по неделям и месяцам:__ Графики демонстрируют, что расходы на рекламу по различным источникам колеблются в зависимости от времени. Это может быть связано с различными рекламными кампаниями или сезонными колебаниями.
# >
# >* __Сравнение источников:__ Некоторые источники имеют более высокие расходы по сравнению с другими. Это может говорить о том, что на них делается больший упор в рекламной стратегии или они считаются более эффективными.
# >
# >* __Тенденции:__ В некоторые моменты времени наблюдаются резкие всплески расходов. Это может указывать на проведение крупных рекламных кампаний или акций.
# >
# >* __Недельные и месячные графики:__ Графики по неделям позволяют увидеть более детальную картину колебаний расходов, в то время как месячные графики демонстрируют общую тенденцию.

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Отличные и наглядные графики 👍
#
# Здорово, когда они подписаны. Так быстрее понять о чем идёт речь на нём.
#
# </div>

# %% [markdown]
# Вместо того чтобы смешивать все каналы на одном графике, где высокие значения могут "затенять" более низкие, можно разбить графики на группы в зависимости от уровня расходов.
# Это поможет лучше понять динамику каждого канала, особенно для тех, которые имеют относительно небольшие затраты.
#
# Попробуем разделить каналы на три группы:
#
# * __Высокие расходы(high)__: Каналы с самыми высокими средними ежемесячными расходами.
#
#
# * __Средние расходы(medium)__: Каналы со средним уровнем расходов.
#
#
# * __Низкие расходы(low)__: Каналы с самыми низкими расходами.
#
# Для начала, определим пороги для каждой группы на основе данных, затем построим графики для каждой группы отдельно.

# %%
# Рассчитываем средние месячные расходы для каждого канала
avg_monthly_costs = monthly_costs.groupby('channel')['costs'].mean().sort_values()

# Определяем пороги для группировки каналов
thresholds = {
    'low': avg_monthly_costs.quantile(0.33),
    'medium': avg_monthly_costs.quantile(0.66),
    'high': avg_monthly_costs.max()
}

# Группировка каналов по порогам
channels_by_group = {
    'low': avg_monthly_costs[avg_monthly_costs <= thresholds['low']].index.tolist(),
    'medium': avg_monthly_costs[(avg_monthly_costs > thresholds['low']) & 
                                (avg_monthly_costs <= thresholds['medium'])].index.tolist(),
    'high': avg_monthly_costs[avg_monthly_costs > thresholds['medium']].index.tolist()
}

# Построение графиков для каждой группы каналов
fig, axes = plt.subplots(nrows=3, ncols=1, figsize=(15, 15))

for i, (group, channels) in enumerate(channels_by_group.items()):
    group_data = monthly_costs[monthly_costs['channel'].isin(channels)]
    for channel in channels:
        sns.lineplot(data=group_data[group_data['channel'] == channel], 
                     x='month', y='costs', label=channel, ax=axes[i])
    axes[i].set_title(f'Динамика изменения расходов для каналов с {group} затратами')
    axes[i].set_xlabel('Месяц')
    axes[i].set_ylabel('Расходы')
    axes[i].legend()
    axes[i].tick_params(axis='x', rotation=45)
    axes[i].grid(True, which='both', linestyle='--', linewidth=0.5)

plt.tight_layout()
plt.show()

# %% [markdown]
# >Разбивая затраты на каналы по уровню расходов и изучая их отдельно, мы можем получить более детальное представление о динамике каждого канала:
# >
# >* __Каналы с высокими расходами:__ Эти каналы, вероятно, представляют основные платформы рекламы для компании, и на них направляется большая часть рекламного бюджета. Оценка их эффективности особенно важна, так как они влияют на большую часть рекламных расходов.
# >
# >
# >* __Каналы со средними расходами:__ Эти каналы могут представлять собой второстепенные или дополнительные платформы рекламы. Они также важны для компании, так как могут дополнять основные каналы или достигать другой аудитории.
# >
# >
# >* __Каналы с низкими расходами:__ Эти каналы могут быть экспериментальными или новыми для компании. Они также могут представлять собой ниши или специализированные платформы. Несмотря на их низкие затраты, важно отслеживать их эффективность, так как они могут предложить уникальные возможности для роста или достижения определенных сегментов рынка.

# %% [markdown]
# **Узнаем, сколько в среднем стоило привлечение одного пользователя (CAC) из каждого источника.
# Используем профили пользователей:**

# %% [markdown]
# Рассчитаем средний CAC на одного пользователя для каждого источника трафика:

# %%
cac_by_channel = profiles.groupby('channel')['acquisition_cost'].agg('mean').sort_values(ascending = False)
cac_by_channel
# Out:
# channel
# TipTop                2.799003
# FaceBoom              1.113286
# AdNonSense            1.008054
# lambdaMediaAds        0.724802
# WahooNetBanner        0.602245
# RocketSuperAds        0.412095
# OppleCreativeMedia    0.250000
# YRabbit               0.218975
# MediaTornado          0.218717
# LeapBob               0.210172
# organic               0.000000
# Name: acquisition_cost, dtype: float64

# %% [markdown]
# Органический трафик (`organic`) — это посетители, которые приходят на ваш сайт через поисковые системы, такие как Яндекс, Yahoo или Bing. Проще говоря, это бесплатный и естественный способ привлечения посетителей на наш сайт, в отличие от платной рекламы или продвижения в социальных сетях.

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Расчёт корректный

# %%
plt.figure(figsize=(18, 6))
sns.barplot(x=cac_by_channel.index, y=cac_by_channel.values, alpha=0.8, palette='Set2')

plt.title('CAC по каналам')
plt.xlabel('Стоимость')
plt.ylabel('Каналы')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# Посчитаем средний САС по проекту:

# %%
cac_by_channel.mean().round(2)
# Out:
# 0.69

# %% [markdown]
# Посчитаем средний САС по проекту без учета органических пользователей:

# %%
print('Средний CAC по проекту:', profiles.query('channel != "organic"')['acquisition_cost'].mean().round(2))
# Out:
# Средний CAC по проекту: 1.13

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Отличный инсайд для заказчика. Молодец!)

# %% [markdown]
# >**Вывод:**
# >
# >* Самыми "дорогими" стали пользователи, привлеченные через рекламные компании `TipTop`.
# >
# >* Среди пользоваталей, пришедших благодаря рекламе, дешевле всего обошлось привлеченние одного пользователя через канал `LeapBob`.
# >
# >* Средний CAC по проекту составил 0,69.
# >
# >* Без учета органических пользоваталей средний cac по проекту составил 1.13.

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Наиболее дорогостоящим каналом привлечения пользователей является TipTop, однако количество и доля платящих пользователей, приходящих с этого источника, не так высоки. Это можно объяснить молодой аудиторией TipTop'a и, соответственно, не очень высокой их платежеспособностью.
#
# </div>

# %% [markdown]
# ### Оцените окупаемость рекламы
#
# Используя графики LTV, ROI и CAC, проанализируйте окупаемость рекламы. Считайте, что на календаре 1 ноября 2019 года, а в бизнес-плане заложено, что пользователи должны окупаться не позднее чем через две недели после привлечения. Необходимость включения в анализ органических пользователей определите самостоятельно.
#
# - Проанализируйте окупаемость рекламы c помощью графиков LTV и ROI, а также графики динамики LTV, CAC и ROI.
# - Проверьте конверсию пользователей и динамику её изменения. То же самое сделайте с удержанием пользователей. Постройте и изучите графики конверсии и удержания.
# - Проанализируйте окупаемость рекламы с разбивкой по устройствам. Постройте графики LTV и ROI, а также графики динамики LTV, CAC и ROI.
# - Проанализируйте окупаемость рекламы с разбивкой по странам. Постройте графики LTV и ROI, а также графики динамики LTV, CAC и ROI.
# - Проанализируйте окупаемость рекламы с разбивкой по рекламным каналам. Постройте графики LTV и ROI, а также графики динамики LTV, CAC и ROI.
# - Ответьте на такие вопросы:
#     - Окупается ли реклама, направленная на привлечение пользователей в целом?
#     - Какие устройства, страны и рекламные каналы могут оказывать негативное влияние на окупаемость рекламы?
#     - Чем могут быть вызваны проблемы окупаемости?
#
# Напишите вывод, опишите возможные причины обнаруженных проблем и промежуточные рекомендации для рекламного отдела.

# %%
# Исключим из дальнейшего анализа органических пользователей
profiles = profiles.query('channel != "organic"')

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Совершенно верно, поскольку мы за них ничего не платим,  а нам нужно изучить именно окупаемость рекламы.
# </div>

# %% [markdown]
# На календаре 1 ноября 2019 года, а в бизнес-плане заложено, что пользователи должны окупаться не позднее чем через две недели после привлечения. Установим момент и горизонт анализа.

# %%
observation_date = datetime(2019, 11, 1).date()  # момент анализа
horizon_days = 14  # горизонт анализа

# %% [markdown]
# **Проанализируем окупаемость рекламы c помощью графиков LTV, ROI и CAC, а также графики динамики LTV, CAC и ROI:**

# %%
# Вызовем функцию для расчета LTV, ROI и их динамики
(
        result_raw,  # сырые данные
        result_grouped,  # таблица LTV
        result_in_time,  # таблица динамики LTV
        roi_grouped,  # таблица ROI
        roi_in_time,  # таблица динамики ROI
    ) = get_ltv(profiles,
                orders_info,
                observation_date,
                horizon_days,
                dimensions=[],
                ignore_horizon=False,)

# Визуализируем полученные показатели на графиках
plot_ltv_roi(result_grouped, result_in_time, roi_grouped, roi_in_time, horizon_days, window=5)

# %% [markdown]
# * LTV пользователя в среднем стабильно растет на протяжении всего лайфтайма - это хороший признак, свидетельствующий об отсутствии проблем в продукте.
#
# * Динамика LTV пользователей на 14 день циклична, однако стабильна на протяжении всего периода - это также указывает на отсутствие проблем в продукте, а также на отсутствие существенных изменений в потребительском поведении за изучаемый период.
#
# * Динамика САС более тревожная - затраты на привлечение одного клиента неуклоннно растут.
#
# Это отрицательно сказывается на ROI - к концу второй недели уровень окупаемости не достигается, выручка едва достигает 80% от понесенных затрат на рекламу.
#
# Динамика ROI показывает, что приложение окупалось только в начале периода наблюдений - в мае. К концу мая произошло одновременно два события - упал органический трафик и начался рост затрат на маркетинг. Как следствие этих двух тенденций мы наблюдаем ухудшение окупаемости рекламы начиная с мая и до конца исследуемого периода.

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Логика анализа верная, согласен с выводом. Наблюдаем, что динамика ROI за лайфтайм падает. При относительно стабильной динамике LTV, динамика САС растёт с мая по конец октября. Эту закономерность мы наблюдаем в динамике ROI, что при сильном увеличении САС, в равной степени падает динамика ROI пользователей.
# </div>

# %% [markdown]
# >* __Стабильность LTV (Lifetime Value):__
# >
# >Если LTV остается стабильным, это может говорить о том, что качество привлеченных пользователей не ухудшилось. Они продолжают приносить такую же выручку, как и раньше.
# >Однако стабильный LTV также может указывать на отсутствие роста в стоимости пожизненной ценности клиента. Это может быть результатом отсутствия инноваций или улучшений в продукте или услуге.
# >
# >* __Рост CAC (Cost of Acquisition):__
# >
# >Если CAC растет, это может говорить о том, что стоимость привлечения одного клиента увеличивается. Это может быть связано с ростом конкуренции на рекламном канале, что приводит к увеличению стоимости клика или показа.
# >Увеличение CAC также может быть результатом увеличения рекламного бюджета без соответствующего увеличения количества привлеченных пользователей.
# >Если рост CAC не сопровождается увеличением LTV, это может быть тревожным сигналом, так как это означает, что затраты на привлечение клиентов растут, но выручка от них остается на прежнем уровне.
# >
# >
# >Таким образом, комбинация стабильного LTV и растущего CAC может указывать на необходимость пересмотра стратегии маркетинга и рекламы. Возможно, стоит искать новые, более эффективные каналы привлечения или оптимизировать текущие рекламные кампании.

# %% [markdown]
# **Проверим конверсию пользователей и динамику её изменения. То же самое сделаем с удержанием пользователей.
# Построим и изучим графики конверсии и удержания:**

# %%
# Вызовем и визуализируем функции для расчета конверсии
result_raw, result_grouped, result_in_time = get_conversion(
    profiles,
    orders_info,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
)

plot_conversion(result_grouped, result_in_time, horizon_days, window=7)

# %% [markdown]
# >Конверсия показывает стабильное увеличение в течении всего лайфтайма, динамика конверсии имеет цикличность однако в целом находится на стабильном уровне.

# %%
# Вызовем и визуализируем функции для расчета удержания пользователей
result_raw, result_grouped, result_in_time = get_retention(
    profiles,
    visits_info,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
)

plot_retention(result_grouped, result_in_time, horizon_days, window=7)

# %% [markdown]
# >Аналогичное поведение показывают и показатели удержания пользователей в течении всего лайфтайма:
# >общее значение показателей не вызывает тревоги, динамика имеет цикличность однако в целом находится на стабильном уровне.
# >Можно также отметить, что удержание платящих пользователей находится на более высоком уровне, чем удержание неплатящих.
# >Все это указывает на отсутствие серьезных проблем непосредственно в самом продукте.

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Хорошо, анализ конверсии и удержания корректен

# %% [markdown]
# **Проанализируем окупаемость рекламы с разбивкой по устройствам. Построим графики LTV и ROI,
# а также графики динамики LTV, CAC и ROI:**

# %%
# Вызовем функцию для расчета LTV, ROI и их динамики
(
        result_raw,  # сырые данные
        result_grouped,  # таблица LTV
        result_in_time,  # таблица динамики LTV
        roi_grouped,  # таблица ROI
        roi_in_time,  # таблица динамики ROI
    ) = get_ltv(profiles,
                orders_info,
                observation_date,
                horizon_days,
                ['device'],
                ignore_horizon=False,)

# Визуализируем полученные показатели на графиках
plot_ltv_roi(result_grouped, result_in_time, roi_grouped, roi_in_time, horizon_days, window=14)

# %% [markdown]
# >* Основные затраты на маркетинг были направлены на пользователей Мак и Айфон.
# >
# >* В результате показатель ROI по этим устройствам находится ниже уровня окупаемости к концу лайфтайма.
# >
# >* Единственное устройство, которое выходит на уровень окупаемости рекламы - это РС,
# >однако и затраты на рекламу на пользователей этих устройств минимальны, в сравнении с остальными гадежтами.

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# С окупаемостью проблемы по всем устройствам кроме PC. Это значит, что у нас, по крайней мере, нет технических проблем, влияющих на монетизацию;
# </div>

# %% [markdown]
# **Проанализируем окупаемость рекламы с разбивкой по странам.
# Построим графики LTV и ROI, а также графики динамики LTV, CAC и ROI:**

# %%
# Вызовем функцию для расчета LTV, ROI и их динамики
(
        result_raw,  # сырые данные
        result_grouped,  # таблица LTV
        result_in_time,  # таблица динамики LTV
        roi_grouped,  # таблица ROI
        roi_in_time,  # таблица динамики ROI
    ) = get_ltv(profiles,
                orders_info,
                observation_date,
                horizon_days,
                ['region'],
                ignore_horizon=False,)

# Визуализируем полученные показатели на графиках
plot_ltv_roi(result_grouped, result_in_time, roi_grouped, roi_in_time, horizon_days, window=14)

# %% [markdown]
# >Страна которая влияет на показатели это __`US`__, хотя LTV у этих пользователей и самое высокое, но ROI опустилось до 55%,
# >расходы на привлечение постоянно растут.
# >Единственная страна которая не преодолевает порог окупаемости.
# >И хотя эта самая большая страна как по количеству пользователей, по количеству платящих пользователй,
# >а также по доле платящих пользователей, затраты на привлечение серьезно превышают уровень окупаемости.

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Все верно. Нужно разбираться детальнее с рекламой в США, тем более, что это наш основной рынок.

# %% [markdown]
# **Проанализируем окупаемость рекламы с разбивкой по рекламным каналам. Построим графики LTV и ROI,
# а также графики динамики LTV, CAC и ROI:**

# %%
profiles_usa = profiles.query("region == 'United States'") # Профили по региону US

# %%
# Считаем LTV и ROI по channel
ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles_usa, orders_info, observation_date, horizon_days, dimensions = ['channel']
)
# Строим графики
plot_ltv_roi(ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days, window=14)

# %% [markdown]
# >У `TipTop` самый высокий LTV, CAC очень сильно растет, уровень окупаемости самый низкий, ROI падает до 50%.
# >У `FaceBoom` стабильный LTV, CAC на одном уровне, но уровень окупаемости преодолеть не может. ROI колеблется в районе 90%.
# >Все остальные каналы практически сразу проходят точку безубыточности.

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Да, действительно, есть проблемы с каналом TipTop, видим значительный рост затрат на привлечение.
# </div>

# %% [markdown]
# **<<< Хочется обратить внимание на сходство стоимости привлечения `US` и `TipTop`!!! >>>**

# %% [markdown]
# >Сходство стоимости привлечения между `US` и `TipTop` может говорить о нескольких вещах:
# >
# >* Особенности рынка:
# >
# >    `TipTop` может быть популярным источником трафика именно в США, и большая часть затрат на этот источник приходится на американский рынок.
# >
# >
# >* Конкуренция:
# >
# >    В США может быть высокая конкуренция на рекламные площадки, особенно в популярных источниках трафика, таких как TipTop. Это может привести к повышению стоимости привлечения.
# >
# >
# >* Целевая аудитория:
# >
# >    TipTop может ориентироваться на определенную целевую аудиторию, которая активно представлена в США. Например, если это источник привлечен для молодежи или профессионалов определенной отрасли, то его популярность и стоимость привлечения могут быть высокими именно на американском рынке.
# >
# >
# >* Бюджет на маркетинг:
# >
# >    Может быть так, что большой бюджет был выделен именно на рекламу в TipTop для американского рынка, что привело к схожести стоимости привлечения.

# %% [markdown]
# **Построим и изучим графики конверсии и удержания в разрезе каналов:**

# %%
# Вызовем и визуализируем функции для расчета конверсии
result_raw, result_grouped, result_in_time = get_conversion(
    profiles,
    orders_info,
    observation_date,
    horizon_days,
    dimensions=['channel'],
    ignore_horizon=False,
)

plot_conversion(result_grouped, result_in_time, horizon_days, window=7)

# %% [markdown]
# >Разделив пользователей по источникам привлечения, мы видим что конверсия существенно отличается между различными источниками.
# >Неплохую конверсию показывают основные источники привлечения - `FaceBoom` и `TipTop`.
# >Другие источники привлекают пользователей с существенно более низкой конверсией.
# >Однако, мы можем наблюдать на графике, что две компании могут похвастаться с результами конверсии наравне с лидерами:
# >это компании `LambdaMediaAds` и `AdNonSense`.
# >При этом последняя нередко выбивается в лидеры по показателю конверси на 14 день.

# %%
# Вызовем и визуализируем функции для расчета удержания пользователей
result_raw, result_grouped, result_in_time = get_retention(
    profiles,
    visits_info,
    observation_date,
    horizon_days,
    dimensions=['channel'],
    ignore_horizon=False,
)

plot_retention(result_grouped, result_in_time, horizon_days, window=7)

# %% [markdown]
# >Отличия в удержании платящих и неплатящих пользователей могут быть связаны с рядом причин:
# >
# >* Качество Трафика:
# >
# >    * Источники трафика: Некоторые каналы привлечения могут привлекать пользователей, которые более склонны к покупке, в то время как другие каналы могут привлекать пользователей, которые просто "заглядывают". Например, пользователи, пришедшие из контекстной рекламы по конкретным запросам, могут быть более мотивированы к покупке, чем пользователи из общих рекламных кампаний в социальных сетях.
# >    * Страны: Платежеспособность и покупательская активность могут сильно различаться в разных странах. В некоторых странах пользователи могут быть более склонны к покупке, в то время как в других - менее.
# >    * Платформы: Пользователи разных платформ (например, iOS vs Android) могут иметь разные паттерны поведения и платежную активность.
# >
# >
# >* Ожидания Пользователей:
# >
# >    * Платящие пользователи, вероятно, имеют определенные ожидания от продукта или услуги. Если эти ожидания не выполняются, они могут быстро уйти. Неплатящие пользователи могут быть менее требовательными.
# >
# >* Взаимодействие с Продуктом:
# >
# >    * Платящие пользователи могут активнее взаимодействовать с продуктом или услугой, что может влиять на их удержание. Например, если они сталкиваются с проблемами или ошибками, это может сильно повлиять на их лояльность.
# >
# >* Сервис и Поддержка:
# >
# >    * Платящие пользователи могут ожидать более высокого уровня обслуживания или поддержки. Если компания не предоставляет адекватной поддержки, это может отрицательно сказаться на удержании платящих пользователей.
# >
# >* Сезонность и Акции:
# >
# >    * Если платящие пользователи привлекаются акциями или скидками, их удержание может быть ниже после завершения акционного периода.

# %% [markdown]
# >Скорее всего в более ровном удержании неплатящих пользователей относительно платящих, виновато число пользователей. Когда говорим об удержании платящих, видим величину изменчивую, непостоянную, но это не из-за её природы, а из-за того, что наблюдений мало, и каждое отдельное наблюдение существенно влияет на оценку.

# %% [markdown]
# **Построим и изучим графики конверсии и удержания в разрезе стран:**

# %%
# Вызовем и визуализируем функции для расчета конверсии
result_raw, result_grouped, result_in_time = get_conversion(
    profiles,
    orders_info,
    observation_date,
    horizon_days,
    dimensions=['region'],
    ignore_horizon=False,
)

plot_conversion(result_grouped, result_in_time, horizon_days, window=7)

# %% [markdown]
# >Конверсия пользователей `US` существенно ниже конверсии пользователей европейского рынка.
# >Однако в начале исследуемого периода был момент, когда эти показатели вышли на сопоставимый уровень по всем регионам;
# >и даже, в моменте, конверсия европейских пользователей превышала конверсию американских пользователей.
# >Исторически это совпадало с периодом, когда у продукта был высокий органический трафик.

# %%
# Вызовем и визуализируем функции для расчета удержания пользователей
result_raw, result_grouped, result_in_time = get_retention(
    profiles,
    visits_info,
    observation_date,
    horizon_days,
    dimensions=['region'],
    ignore_horizon=False,
)

plot_retention(result_grouped, result_in_time, horizon_days, window=7)

# %% [markdown]
# >Удержание неплатящих пользователей выглядит примерно одинаково по всем регионам, и не имеет существенного значения.
# >Однако анализ удержания по регионам показывает, что пользователи из США быстрее перестают пользоваться продуктом.
# >Это коррелирует с выводом предыдущего пункта: основные привлеченные компаниями `FaceBoom` и `TipTop` пользователи - американцы, и они проявляют интерес к продукту недолгое время.

# %% [markdown]
# **Построим и изучим графики конверсии и удержания в разрезе устройств:**

# %%
# Вызовем и визуализируем функции для расчета конверсии
result_raw, result_grouped, result_in_time = get_conversion(
    profiles,
    orders_info,
    observation_date,
    horizon_days,
    dimensions=['device'],
    ignore_horizon=False,
)

plot_conversion(result_grouped, result_in_time, horizon_days, window=7)

# %% [markdown]
# >Конверсия пользователей Мак и Айфон выше, чем пользователей Андроида и РС.
# >Возможно, есть какие-либо отличия в версиях приложения на различных платформах.

# %%
# Вызовем и визуализируем функции для расчета удержания пользователей
result_raw, result_grouped, result_in_time = get_retention(
    profiles,
    visits_info,
    observation_date,
    horizon_days,
    dimensions=['device'],
    ignore_horizon=False,
)

plot_retention(result_grouped, result_in_time, horizon_days, window=7)

# %% [markdown]
# >Удержание пользователей по всем устройствам выглядит примерно одинаково.

# %% [markdown]
# Проведенный анализ окупаемости затрат на рекламу позволяет сделать следующие выводы:
#
# >* Показатели продуктовой бизнесс-аналитики находятся на приемлимом уровне:
# >    на протяжении всего жизненного цикла не выявлено каких-либо серьезных проблем с LTV, конверсией или удержанием пользователей.
# >
# >* Проведенная на протяжении исследуемого периода агресивная рекламная политика, направленная на привлечение пользователей из Соединенных Штатов силами двух рекламных компаний (`FaceBoom` и `TipTop`), оказалась провальной с точки зрения окупаемости, и привела к тяжелым экономическим последствиям для всего продукта в целом.
# >
# >* Альтернативный европейский рынок выглядит привлекательным с точки зрения эффективности инвестиций, однако его объем в общей доле не слишком велик.

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Согласен с интерпретацией результатов. Проблемные источники определены верно.

# %% [markdown]
# ### Напишите выводы
#
# - Выделите причины неэффективности привлечения пользователей.
# - Сформулируйте рекомендации для отдела маркетинга.

# %% [markdown]
# **ВЫВОД:**
#
#     Изучив пользоваталей, привлеченных с 1 мая 2019 года по 27 октября 2019 года, сделали следующие наблюдения:
#     больше всего платящих пользователей приходит из США, используют iphone и были привлечены рекламной компанией в
#     `FaceBoom`.
#     Наименьшая доля платящих пользователей - во Франции, при этом в абсолютном количестве меньше всего платящих
#     пользоваталей приходится на Германию.
#     Большинство клиентов используют iphone, платящие пользователи также предпочитают эти устройства. При этом наибольшая
#     доля платящих пользователей - среди владельцев mac,хотя в абсолютном значении количество платящих пользователей mac
#     существенно ниже iphone. Наименьшая доля платящих пользователей - среди клиентов, использующих pc.
#     Самым результативным источником привлечения оказалась рекламная компания в `FaceBoom`. На нее же приходится наибольшая
#     доля и наиболшее число платящих клиентов. В абсютном количестве привлеченных плательщиков хуже всего оказалась
#     рекламная компания MediaTornado. Канал LambdaMediaAds привлек меньше всего клиентов, при этом доля плательщиков
#     в нем составила более 10% - возможно следует увеличить расходы на рекламу в этом источнике.
#     Суммарные расходны на рекламную компанию составили более 105 млн. Больше всего денег потратили на рекламные компании
#     TipTop и FaceBoom, на порядок выше всех остальных рекламных источников. Самыми дешевыми оказались рекламные
#     компании YRabbit. Самыми "дорогими" стали пользователи, привлеченные через рекламные компании TipTop.
#     Показатели продуктовой бизнесс-аналитики находятся на приемлимом уровне:
#     на протяжении всего жизненного цикла не выявлено каких-либо серьезных проблем с LTV, конверсией или удержанием
#     пользователей.
#     Центр экономических интересов приложения находится, на данный момент, в США.
#     Именно там сосредоточена большая часть пользователей, в том числе платящих. Европейский рынок представленный тремя
#     странами, в совокупности уступает по объемам американскому рынку.
#     Традиционно устройства, преобладающие на американском рынке - это iphone и mac.
#     На данный момент основными источниками генерации рекламного траффика являются рекламные компании FaceBoom и TipTop.
#     Эти же компании входят в топ компаний поставляющих траффик самого высокого качества. При этом лидером по затратам на
#     маркетинг является TipTop, в то время как лидером по привлечению пользователей является FaceBoom.
#     Прочие компании заметно отстают по основным объемным показателям, однако некоторые компании не уступают лидерам с точки
#     зрения эффективности.

# %% [markdown]
# **На основании выводов можно дать следующие рекомендации для отдела маркетинга:**
#
#     Пересмотреть рекламную политику в отношении продвижения продукта в первую очередь на рынке США.
#     С точки зрения эфективности инвестиций, европейский рынок выглядит привлекательным, не смотря на то, что его объём
#     не слишком велик в общей доле.
#     Следует направить маркетинговые усилия на увеличение доли данного рынка, а также на пользователей РС, Андроид и других
#     девайсов, традиционно занимающих большую долю на европейском рынке.
#     Нужно поработать с органическими пользователями: это существенная доля дохода приложения.
#     Следует пересмотреть затраты маркетинга в отношение компании `TipTop`:
#     рост затрат на рекламные услуги этой компании стал основным фактором снижения эффективности в исследуемом периоде,
#     поскольку не принес сопоставимых результатов в виде увеличения пользователей (в том числе платящих).

# %% [markdown]
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №1__
#
# Шикарный вывод, молодец, что в итоговом выводе сформулировал рекомендации для отдела маркетинга: про каналы, от которых стоит отказаться (обратить внимаение) ты упомянул, давай предложим альтернативные каналы, по которому показатели конверсии, удержания и ROI на приемлемом уровне. Как думаешь, а канал `Yrabbit` и `RocketSuperAds` подойдут?

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарии студента:</b>  Анализ по каналам YRabbit и RocketSuperAds .</div>

# %%
# Объединяем датафреймы orders_info и visits_info по user_id для получения информации о канале
merged_data = orders_info.merge(visits_info, on='user_id')

# Фильтруем данные для каналов 'YRabbit' и 'RocketSuperAds'
filtered_data = merged_data[merged_data['channel'].isin(['YRabbit', 'RocketSuperAds'])]

# Рассчитываем общее количество и платящих пользователей для каждого канала
channel_users = filtered_data.groupby('channel').agg(
    total_users=('user_id', 'nunique'),
    paying_users=('user_id', pd.Series.nunique)
)

# Рассчитываем коэффициент конверсии
channel_users['conversion_rate'] = (channel_users['paying_users'] / channel_users['total_users']) * 100

channel_users = channel_users.rename(columns={
    'total_users': 'Общее_количество_пользователей',
    'paying_users': 'Платящие_пользователи',
    'conversion_rate': 'Коэффициент_конверсии'
})
channel_users
# Out:
#                 Общее_количество_пользователей  Платящие_пользователи  \
# channel
# RocketSuperAds                             558                    558
# YRabbit                                    380                    380
#
#                 Коэффициент_конверсии
# channel
# RocketSuperAds                  100.0
# YRabbit                         100.0

# %% [markdown]
# **Дополнительные рекомендации для отдела маркетинга:**
#
# `RocketSuperAds` и `YRabbit`:
#
# Оба канала показали идеальную конверсию в 100%.
# Это может указывать на высокую эффективность этих каналов или на наличие искажений в данных. Дополнительно проверим данные на наличие аномалий. Если данные корректны, то стоит увеличить инвестиции в эти каналы, так как они показывают отличные результаты по конверсии.

# %%
# Извлекаем месяц из даты начала сессии
merged_data['session_month'] = merged_data['session_start'].astype('datetime64[M]')

# Определяем когорты на основе месяца первой сессии
merged_data['cohort_month'] = merged_data.groupby('user_id')['session_month'].transform('min')

# Фильтруем данные для каналов 'YRabbit' и 'RocketSuperAds'
filtered_data = merged_data[merged_data['channel'].isin(['YRabbit', 'RocketSuperAds'])]

# Рассчитываем retention для отфильтрованных данных
cohorts = filtered_data.groupby(['cohort_month', 'session_month']).agg(total_users=('user_id', 'nunique')).reset_index()
initial_users_count = cohorts[cohorts['cohort_month'] == cohorts['session_month']][['cohort_month', 'total_users']]
initial_users_count = initial_users_count.rename(columns={'total_users': 'cohort_users'})
cohorts = cohorts.merge(initial_users_count, on='cohort_month')
cohorts['retention'] = cohorts['total_users'] / cohorts['cohort_users']

# Трансформируем таблицу для лучшей визуализации
retention_pivot = cohorts.pivot_table(index='cohort_month', columns='session_month', values='retention', aggfunc='sum')

retention_pivot
# Out:
# session_month  2019-05-01  2019-06-01  2019-07-01  2019-08-01  2019-09-01  \
# cohort_month
# 2019-05-01            1.0    0.935897    0.929487    0.891026    0.833333
# 2019-06-01            NaN    1.000000    0.928571    0.693878    0.693878
# 2019-07-01            NaN         NaN    1.000000    0.900990    0.801980
# 2019-08-01            NaN         NaN         NaN    1.000000    0.887850
# 2019-09-01            NaN         NaN         NaN         NaN    1.000000
# 2019-10-01            NaN         NaN         NaN         NaN         NaN
#
# session_month  2019-10-01
# cohort_month
# 2019-05-01       0.788462
# 2019-06-01       0.734694
# 2019-07-01       0.712871
# 2019-08-01       0.757009
# 2019-09-01       0.843478
# 2019-10-01       1.000000

# %% [markdown]
# Определили когорты на основе месяца первого визита пользователя и рассчитали Retention Rate для каждой когорты на протяжении 6 месяцев.
#
# В таблице выше представлены значения Retention Rate для каналов YRabbit и RocketSuperAds:
#
# * Первая когорта (Май 2019) начала с Retention Rate 100% (как и все начальные когорты), и к октябрю 2019 года показатель уменьшился до 78.8%.
# * Для когорты Июнь 2019, Retention Rate уменьшился до 73.5% к октябрю 2019 года.
#
#
# И так далее для каждой когорты.

# %% [markdown]
# Чтобы проверить данные на наличие аномалий, мы можем воспользоваться различными методами:
#
# * Графический анализ: Построим графики распределения и ящик с усами (box plot) для определения выбросов.
# * Статистический анализ: Используем методы, такие как IQR (межквартильный размах) для выявления аномальных значений.

# %%
# Строим графики распределения и "ящик с усами" для стоимости заказов
fig, ax = plt.subplots(1, 2, figsize=(15, 5))

# График распределения
sns.histplot(orders_info['revenue'], bins=50, kde=True, ax=ax[0])
ax[0].set_title('Распределение стоимости заказов')
ax[0].set_xlabel('Стоимость заказа')
ax[0].set_ylabel('Количество заказов')

# Ящик с усами
sns.boxplot(x=orders_info['revenue'], ax=ax[1])
ax[1].set_title('Ящик с усами для стоимости заказов')
ax[1].set_xlabel('Стоимость заказа')

plt.tight_layout()
plt.show()

# %% [markdown]
# На основе представленных графиков можно сделать следующие выводы:
#
# * Распределение стоимости заказов: Большинство заказов имеют стоимость в пределах 5 единиц. Распределение является одномодальным с одним пиком около значения 5.
# * Ящик с усами: Медианное значение стоимости заказа составляет около 5 единиц, и большинство заказов находятся в этом диапазоне.
# Нет явных выбросов или аномальных значений.
#
#
# Таким образом, данные по стоимости заказов не содержат видимых аномалий или выбросов.

# %% [markdown]
# Теперь перейдем к расчету ROI для каналов YRabbit и RocketSuperAds:

# %%
# Рассчитываем общие затраты для каждого канала
channel_costs = costs_info.groupby('channel').agg(total_costs=('costs', 'sum'))

# Фильтруем данные затрат для каналов 'YRabbit' и 'RocketSuperAds'
filtered_costs = channel_costs[channel_costs.index.isin(['YRabbit', 'RocketSuperAds'])]

# Рассчитываем общий доход для каждого канала
channel_revenue = filtered_data.groupby('channel').agg(total_revenue=('revenue', 'sum'))

# Объединяем два датафрейма для расчета ROI
roi_data = filtered_costs.merge(channel_revenue, left_index=True, right_index=True, how='left').fillna(0)

# Рассчитываем ROI
roi_data['ROI'] = ((roi_data['total_revenue'] - roi_data['total_costs']) / roi_data['total_costs']) * 100

roi_data = roi_data.rename(columns={
    'total_costs': 'Общие_затраты',
    'total_revenue': 'Общий_доход',
    'ROI': 'ROI (%)'
})
roi_data
# Out:
#                 Общие_затраты  Общий_доход       ROI (%)
# channel
# RocketSuperAds        1833.00    236299.58  12791.411893
# YRabbit                944.22    111412.80  11699.453517

# %% [markdown]
# Вот результаты расчета ROI для каналов "RocketSuperAds" и "YRabbit":
#
# RocketSuperAds:
# * Общие затраты: $1833.00
#
# * Общий доход: $236299.58
#
# * ROI: 12791.41%
#
#
#
#
#
# YRabbit:
# * Общие затраты: $944.22
#
# * Общий доход: $111412.80
#
# * ROI: 11699.45%
#
#
# Оба канала показывают впечатляющий ROI, что делает их очень эффективными с точки зрения возврата на инвестиции в рекламу.

# %% [markdown]
# **На основе проведенного анализа для каналов "RocketSuperAds" и "YRabbit" можно сделать следующие выводы:**
#
# * __Эффективность каналов:__
# Оба канала показывают высокую эффективность в привлечении платящих клиентов. Это подтверждается 100% коэффициентом конверсии и впечатляющими показателями ROI.
#
# * __Затраты и доходы:__
#     * `RocketSuperAds`: несмотря на затраты 1833 дол. , этот канал принес доход в размере 236299 дол.
#
#     * `YRabbit`: Затраты составили 944.22 дол, а доход — 111412.80 дол.
#
#
# Это говорит о том, что вложения в эти каналы окупаются с лихвой.
#
# ROI:
#
# `RocketSuperAds` показывает ROI в 12791.41%, что означает, что на каждый потраченный доллар приходится прибыль в 127.91 дол.
# `YRabbit` имеет ROI в 11699.45 дол, что соответствует прибыли в 116.99 дол., на каждый потраченный доллар.
#
#
# **Заключение:**
#
# Каналы `RocketSuperAds` и `YRabbit` являются выдающимися с точки зрения эффективности и возврата на маркетинговые инвестиции.
#
# Рекомендуется увеличить вложения в эти каналы или, по крайней мере, поддерживать текущий уровень инвестирования для оптимизации прибыли.

# %% [markdown]
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №2__
#
# Я бы не рекомендовал вкладываться в канал `Yrabbit`. Почему я так думаю: да, канал сейчас окупается, потому что там низкий CAC. Фактически мы сейчас сильно много не платим за новых клиентов (CAC = 0,21) . И уже на этих клиентах (которые обошлись нам недорого) мы сможем спрогнозировать будущую картину. Они имеют низкую конвертируемость и сильно падающее удержание на последних днях горизонта. Т.е. можно сделать вывод, что им не интересно наше приложение. Возможно, это просто не наша аудитория. Они не заинтересованы в нашем приложении

# %% [markdown]
# **Наблюдения:**
#
# * Высокий ROI может указывать на ошибку в данных или неправильный расчет.
#
#
# * В некоторых случаях высокий ROI может быть результатом низких первоначальных затрат, а не высокой абсолютной прибыли.
#
#
# * Высокий ROI в прошлом не гарантирует таких же результатов в будущем.

# %% [markdown]
# <div class="alert alert-block alert-warning">📝
# Комментарий от ревьюера №1 </b>
#
#
#
# У тебя получилась очень сильная и хорошая работа. Здорово, что расчеты ты сопровождаешь иллюстрациями, а так же не забываешь про комментарии, твой проект интересно проверять.
#
# ---
#
# Нужно поправить:
#
# 1) Ничего, отличная работа
#
# ----
#
#
# Если у тебя будут какие-то вопросы по моим комментариям - обязательно пиши! Буду ждать работу на повторное ревью :)</div>

# %% [markdown]
# <div style="border:solid blue 3px; padding: 20px">
# <div class="alert alert-block alert-success">✔️
#
#
# __Коментарий от ревьюера №2__
#
#
# В остальном всё чудно😊. Твой проект так и просится на github =)
#
# Поздравляю с успешным завершением проекта 😊👍
# И желаю успехов в новых работах 😊
#
# ---
#
# От себя хочу порекомендовать тебе отличный материал про продуктовую аналитику Дмитрия Животворева.
#
# https://www.youtube.com/watch?v=Vy_rq-x9QEo
